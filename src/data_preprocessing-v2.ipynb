# %% [markdown]
# This version is specifically designed for a short dataset following pengchen's work and only looking at 4 AES

# %%
import pandas as pd

# read log data
with open('../raw data/training-log-corpus.log', 'r') as f:
    logs = f.readlines()

last_time = 0.0
last_student = ''
action_count = 0
l = []
for i, line in enumerate(logs):
    tokens = line.split('\n')[0]
    tokens = tokens.split('|')

    student_id = tokens[0]
    if len(student_id) != 8:
        print(
            f"ERROR: in line {i}, student id length should be 8, found {len(student_id)}!"
        )
        exit(0)

    action = tokens[1]

    # starting entries do not have time
    try:
        float(tokens[2])
    except:
        tokens.insert(2, 0.0)
    time = float(tokens[2])

    if last_student != student_id:
        last_time = 0.0
        print(f"{action_count} actions found for student {last_student}")
        action_count = 0

    # check is time is almost monotonic
    if last_time - time >= 1:
        print(
            f"ERROR: in line {i}, time is not monotonic! current action {action}. total action found {action_count}. student {student_id}"
        )

    last_time = time
    last_student = student_id
    action_count += 1

    try:
        detail = tokens[3]
    except:
        detail = ""

    others = ("|").join(tokens[4:])

    l.append({
        'student_id': student_id,
        'action': action,
        'time': time,
        'detail': detail,
        'others': others
    })

df = pd.DataFrame(l,
                  columns=['student_id', 'action', 'time', 'detail', 'others'])


# for students with "RESET"
# we are keeping if student reseted after planing signifcant part of the game (>70%)
# or resetted very early (<30%)
print("-- removing reset issues --")
dlt_idx = []
student_with_reset = df.loc[df['action'] == 'RESET']['student_id'].unique()
for student in student_with_reset:
    df_s = df.loc[df['student_id'] == student]
    total_steps = len(df_s)
    i = df.loc[(df['student_id'] == student)
               & (df['action'] == 'RESET')].index[0]
    before_reset_steps = len(df_s.loc[:i])
    percent_before_reset = round(before_reset_steps / total_steps * 100, 2)
    drop_curr = []
    if percent_before_reset < 30.0:
        drop_curr = list(df_s.loc[df_s.index[0]:i + 1].index)
    elif percent_before_reset > 70.0:
        drop_curr = list(df_s.loc[i:].index)
    else:
        drop_curr = list(df_s.index)

    print(
        "student: {0} | total_steps: {1} | reset_at: {2}({3}%) | dropping: {4}"
        .format(student, total_steps, before_reset_steps, percent_before_reset,
                len(drop_curr)))
    dlt_idx += drop_curr
    

df = df.drop(index=dlt_idx).reset_index(drop=True)
# Out:
# 0 actions found for student
# 908 actions found for student 100-0001
# 737 actions found for student 100-0003
# 605 actions found for student 100-0004
# 851 actions found for student 100-0005
# 705 actions found for student 100-0006
# 708 actions found for student 100-0007
# 816 actions found for student 100-0008
# 624 actions found for student 100-0009
# 1183 actions found for student 100-0010
# 1132 actions found for student 100-0011
# 799 actions found for student 100-0012
# 854 actions found for student 100-0013
# 836 actions found for student 100-0014
# 631 actions found for student 100-0016
# 1291 actions found for student 100-0017
# 585 actions found for student 100-0018
# 873 actions found for student 100-0019
# 897 actions found for student 100-0020
# 683 actions found for student 100-0021
# 790 actions found for student 100-0022
# 596 actions found for student 100-0024
# 575 actions found for student 100-0025
# 883 actions found for student 100-0026
# 955 actions found for student 100-0027
# 883 actions found for student 100-0028
# 1148 actions found for student 100-0029
# 1018 actions found for student 100-0030
# 616 actions found for student 100-0491
# 743 actions found for student 100-0492
# 424 actions found for student 100-0493
# 658 actions found for student 100-0494
# 613 actions found for student 100-0495
# 662 actions found for student 100-0496
# 891 actions found for student 100-0498
# 1171 actions found for student 100-0499
# 782 actions found for student 100-0500
# 474 actions found for student 100-0501
# 1054 actions found for student 100-0502
# 779 actions found for student 100-0504
# 870 actions found for student 100-0505
# 673 actions found for student 100-0506
# 673 actions found for student 100-0507
# ERROR: in line 328796, time is not monotonic! current action RESET. total action found 916. student 100-0508
# 1254 actions found for student 100-0508
# 275 actions found for student 100-0509
# 813 actions found for student 100-0510
# 607 actions found for student 100-0511
# 867 actions found for student 100-0512
# 580 actions found for student 100-0513
# 496 actions found for student 100-0514
# 614 actions found for student 100-0515
# 690 actions found for student 100-0516
# 680 actions found for student 100-0827
# -- removing reset issues --
# student: 100-0058 | total_steps: 905 | reset_at: 191(21.1%) | dropping: 192
# student: 100-0082 | total_steps: 1462 | reset_at: 1336(91.38%) | dropping: 127
# student: 100-0084 | total_steps: 898 | reset_at: 756(84.19%) | dropping: 143
# student: 100-0122 | total_steps: 834 | reset_at: 355(42.57%) | dropping: 834
# student: 100-0142 | total_steps: 1382 | reset_at: 502(36.32%) | dropping: 1382
# student: 100-0159 | total_steps: 916 | reset_at: 715(78.06%) | dropping: 202
# student: 100-0195 | total_steps: 999 | reset_at: 349(34.93%) | dropping: 999
# student: 100-0307 | total_steps: 1397 | reset_at: 706(50.54%) | dropping: 1397
# student: 100-0322 | total_steps: 1125 | reset_at: 1022(90.84%) | dropping: 104
# student: 100-0508 | total_steps: 1254 | reset_at: 917(73.13%) | dropping: 338

# %%
from collections import defaultdict

# creating action to feature maps
action_map = {
    'DIALOG': 's_dialog_turn',
    'OPEN': 's_open_door',
    'CLOSE' : 's_close_door',
    'LOOKSTART': 's_view_poster',
    'PDAUSE': 's_take_quiz',
    'PICKUP': 's_pickup_obj',
    'DROP': 's_drop_obj',
    'TESTOBJECT': 's_test_obj',
    'WORKSHEET': 's_diagnosis_worksheet',
    'PDAOPEN': 's_use_pda',
    'LABELING': 's_label_slide',
    'NOTES': 's_take_note',
    'BOOKREAD': 's_read_book',
    'BRYCECOMPUTER': 's_bryce_computer',
    'GAMEOVER': 's_end_game'
}

# TALK action needs to be segmented further for narrative planner
action_talk_map = {
    'cur-action-talk-bryce': 's_talk_bryce',
    'cur-action-talk-teresa': 's_talk_teresa', 
    'cur-action-talk-ford': 's_talk_ford', 
    'cur-action-talk-quentin': 's_talk_quentin', 
    'cur-action-talk-robert': 's_talk_robert', 
    
    'cur-action-talk-extraa': 's_talk_others',
    'cur-action-talk-extrab': 's_talk_others',
    'cur-action-talk-elise': 's_talk_others',
    'cur-action-talk-kim': 's_talk_others',
    
}

# all types of adaptions. Not using mystry quiz (as this has 8 choise) and off-task behavior (not enough sample)
adaption_map = {
    'select-bryce-symptoms-level': 's_aes_bryce_symptoms',
    'select-teresa-symptoms-level': 's_aes_teresa_symptoms',
    'select-present-quiz': 's_aes_knowledge_quiz',
    'select-worksheet-level': 's_aes_diagnosis_feedback',
}

states = ['s_time_passed'] + list(set(action_talk_map.values())) + list(action_map.values()) + list(adaption_map.values())

init_row = defaultdict()
for state in states:
    init_row[state] = 0

# %% [markdown]
# - do we need SOLUTION for s_aes_mystry_solution?
# - kim revel adaption points player towards quentin's revel
# - removing students who did restart. maybe worthwhile to include them later
# - 21 students didn't do pretest. thus nlg none. removing them. maybe worthwhile to include them later

# %%
from copy import deepcopy

skipping_action = set()
skipping_adaption = set()
all_student_inserts = []
all_narrative_inserts = []
dlt_students = []
for student_id, rows in df.groupby(['student_id']):
    row_insert = deepcopy(init_row)
    row_insert['student_id'] = student_id
    row_insert['step'] = 0
    row_insert['done'] = False
    narrative_step = 0

    for i, row in rows.iterrows():
        if row['action'] == 'ADAPTATION':
            if row['detail'] not in adaption_map.keys():
                skipping_adaption.add(row['detail'])
                continue

            for adapt_feature in adaption_map.values():
                row_insert[adapt_feature] = 0

            row_insert[adaption_map[row['detail']]] = int(row['others'][-1:])

            narrative_row_insert = deepcopy(row_insert)
            narrative_row_insert['s_time_passed'] = row['time']
            narrative_row_insert['step'] = narrative_step
            narrative_row_insert['action'] = int(row['others'][-1:])

            all_narrative_inserts.append(deepcopy(narrative_row_insert))
            narrative_step += 1
            continue

        if row['action'] == 'TALK':
            char = row['others'].split('|')[0]
            if char not in action_talk_map.keys():
                print(
                    "-- ERROR TALK UNKNOWN | action: {0} | detail: {1} | others: {2} --"
                    .format(row['action'], row['detail'], row['others']))
                break
            row_insert[action_talk_map[char]] += 1
            action = action_talk_map[char]

        elif row['action'] in action_map.keys():
            row_insert[action_map[row['action']]] += 1
            action = action_map[row['action']]
        else:
            skipping_action.add(row['action'])
            if row['action'] == 'RESET':
                print(
                    "-- RESET happened for student {0} --".format(student_id))
                dlt_students.append(student_id)
#             print("-- skipping action | action: {0} | detail: {1} | others: {2} --".format(row['action'], row['detail'], row['others']))
            continue

        row_insert['s_time_passed'] = row['time']
        row_insert['action'] = action
        all_student_inserts.append(deepcopy(row_insert))
        row_insert['step'] += 1

    all_student_inserts[-1]['done'] = True
    all_narrative_inserts[-1]['done'] = True

    print('-- finished student {0} --'.format(student_id))

df_student_data = pd.DataFrame(all_student_inserts,
                               columns=['student_id', 'step'] + states +
                               ['action', 'done'])
df_narrative_data = pd.DataFrame(all_narrative_inserts,
                                 columns=['student_id', 'step'] + states +
                                 ['action', 'done'])

df_student_data = df_student_data.loc[~df_student_data['student_id'].
                                      isin(dlt_students)]
df_student_data = df_student_data.reset_index(drop=True)

df_narrative_data = df_narrative_data.loc[~df_narrative_data['student_id'].
                                          isin(dlt_students)]
df_narrative_data = df_narrative_data.reset_index(drop=True)

print("Actions skipped", skipping_action)
print("Adaptions skipped", skipping_adaption)
print("Removing {0} students for Restarting".format(len(dlt_students)))
# Out:
# -- finished student 100-0001 --
# -- finished student 100-0003 --
# -- finished student 100-0004 --
# -- finished student 100-0005 --
# -- finished student 100-0006 --
# -- finished student 100-0007 --
# -- finished student 100-0008 --
# -- finished student 100-0009 --
# -- finished student 100-0010 --
# -- finished student 100-0011 --
# -- finished student 100-0012 --
# -- finished student 100-0013 --
# -- finished student 100-0014 --
# -- finished student 100-0016 --
# -- finished student 100-0017 --
# -- finished student 100-0018 --
# -- finished student 100-0019 --
# -- finished student 100-0020 --
# -- finished student 100-0021 --
# -- finished student 100-0022 --
# -- finished student 100-0024 --
# -- finished student 100-0025 --
# -- finished student 100-0026 --
# -- finished student 100-0027 --
# -- finished student 100-0028 --
# -- finished student 100-0029 --
# -- finished student 100-0030 --
# -- finished student 100-0031 --
# -- finished student 100-0032 --
# -- finished student 100-0033 --
# -- finished student 100-0034 --
# -- finished student 100-0035 --
# -- finished student 100-0037 --
# -- finished student 100-0038 --
# -- finished student 100-0039 --
# -- finished student 100-0040 --
# -- finished student 100-0041 --
# -- finished student 100-0042 --
# -- finished student 100-0043 --
# -- finished student 100-0044 --
# -- finished student 100-0045 --
# -- finished student 100-0046 --
# -- finished student 100-0047 --
# -- finished student 100-0048 --
# -- finished student 100-0049 --
# -- finished student 100-0050 --
# -- finished student 100-0052 --
# -- finished student 100-0053 --
# -- finished student 100-0054 --
# -- finished student 100-0055 --
# -- finished student 100-0056 --
# -- finished student 100-0057 --
# -- RESET happened for student 100-0058 --
# -- finished student 100-0058 --
# -- finished student 100-0059 --
# -- finished student 100-0060 --
# -- finished student 100-0061 --
# -- finished student 100-0062 --
# -- finished student 100-0063 --
# -- finished student 100-0064 --
# -- finished student 100-0065 --
# -- finished student 100-0066 --
# -- finished student 100-0067 --
# -- finished student 100-0068 --
# -- finished student 100-0069 --
# -- finished student 100-0070 --
# -- finished student 100-0071 --
# -- finished student 100-0072 --
# -- finished student 100-0073 --
# -- finished student 100-0074 --
# -- finished student 100-0075 --
# -- finished student 100-0076 --
# -- finished student 100-0077 --
# -- finished student 100-0078 --
# -- finished student 100-0079 --
# -- finished student 100-0080 --
# -- finished student 100-0081 --
# -- RESET happened for student 100-0082 --
# -- finished student 100-0082 --
# -- finished student 100-0083 --
# -- RESET happened for student 100-0084 --
# -- finished student 100-0084 --
# -- finished student 100-0085 --
# -- finished student 100-0086 --
# -- finished student 100-0087 --
# -- finished student 100-0088 --
# -- finished student 100-0089 --
# -- finished student 100-0090 --
# -- finished student 100-0091 --
# -- finished student 100-0093 --
# -- finished student 100-0095 --
# -- finished student 100-0096 --
# -- finished student 100-0097 --
# -- finished student 100-0099 --
# -- finished student 100-0100 --
# -- finished student 100-0101 --
# -- finished student 100-0102 --
# -- finished student 100-0103 --
# -- finished student 100-0105 --
# -- finished student 100-0106 --
# -- finished student 100-0107 --
# -- finished student 100-0108 --
# -- finished student 100-0109 --
# -- finished student 100-0110 --
# -- finished student 100-0111 --
# -- finished student 100-0112 --
# -- finished student 100-0113 --
# -- finished student 100-0114 --
# -- finished student 100-0115 --
# -- finished student 100-0116 --
# -- finished student 100-0117 --
# -- finished student 100-0118 --
# -- finished student 100-0120 --
# -- finished student 100-0121 --
# -- RESET happened for student 100-0122 --
# -- finished student 100-0122 --
# -- finished student 100-0123 --
# -- finished student 100-0124 --
# -- finished student 100-0125 --
# -- finished student 100-0126 --
# -- finished student 100-0127 --
# -- finished student 100-0128 --
# -- finished student 100-0129 --
# -- finished student 100-0130 --
# -- finished student 100-0132 --
# -- finished student 100-0133 --
# -- finished student 100-0134 --
# -- finished student 100-0135 --
# -- finished student 100-0136 --
# -- finished student 100-0138 --
# -- finished student 100-0139 --
# -- finished student 100-0140 --
# -- finished student 100-0141 --
# -- RESET happened for student 100-0142 --
# -- finished student 100-0142 --
# -- finished student 100-0143 --
# -- finished student 100-0144 --
# -- finished student 100-0145 --
# -- finished student 100-0146 --
# -- finished student 100-0147 --
# -- finished student 100-0148 --
# -- finished student 100-0149 --
# -- finished student 100-0150 --
# -- finished student 100-0151 --
# -- finished student 100-0152 --
# -- finished student 100-0154 --
# -- finished student 100-0155 --
# -- finished student 100-0156 --
# -- finished student 100-0158 --
# -- RESET happened for student 100-0159 --
# -- finished student 100-0159 --
# -- finished student 100-0160 --
# -- finished student 100-0161 --
# -- finished student 100-0163 --
# -- finished student 100-0164 --
# -- finished student 100-0165 --
# -- finished student 100-0166 --
# -- finished student 100-0167 --
# -- finished student 100-0168 --
# -- finished student 100-0169 --
# -- finished student 100-0170 --
# -- finished student 100-0172 --
# -- finished student 100-0174 --
# -- finished student 100-0175 --
# -- finished student 100-0176 --
# -- finished student 100-0177 --
# -- finished student 100-0179 --
# -- finished student 100-0180 --
# -- finished student 100-0181 --
# -- finished student 100-0182 --
# -- finished student 100-0183 --
# -- finished student 100-0184 --
# -- finished student 100-0185 --
# -- finished student 100-0186 --
# -- finished student 100-0187 --
# -- finished student 100-0188 --
# -- finished student 100-0189 --
# -- finished student 100-0190 --
# -- finished student 100-0191 --
# -- finished student 100-0192 --
# -- finished student 100-0193 --
# -- RESET happened for student 100-0195 --
# -- finished student 100-0195 --
# -- finished student 100-0196 --
# -- finished student 100-0198 --
# -- finished student 100-0199 --
# -- finished student 100-0200 --
# -- finished student 100-0201 --
# -- finished student 100-0203 --
# -- finished student 100-0204 --
# -- finished student 100-0205 --
# -- finished student 100-0207 --
# -- finished student 100-0208 --
# -- finished student 100-0209 --
# -- finished student 100-0210 --
# -- finished student 100-0211 --
# -- finished student 100-0212 --
# -- finished student 100-0213 --
# -- finished student 100-0214 --
# -- finished student 100-0215 --
# -- finished student 100-0216 --
# -- finished student 100-0218 --
# -- finished student 100-0219 --
# -- finished student 100-0220 --
# -- finished student 100-0221 --
# -- finished student 100-0222 --
# -- finished student 100-0223 --
# -- finished student 100-0224 --
# -- finished student 100-0225 --
# -- finished student 100-0226 --
# -- finished student 100-0227 --
# -- finished student 100-0228 --
# -- finished student 100-0229 --
# -- finished student 100-0231 --
# -- finished student 100-0232 --
# -- finished student 100-0233 --
# -- finished student 100-0235 --
# -- finished student 100-0236 --
# -- finished student 100-0237 --
# -- finished student 100-0238 --
# -- finished student 100-0239 --
# -- finished student 100-0241 --
# -- finished student 100-0242 --
# -- finished student 100-0243 --
# -- finished student 100-0244 --
# -- finished student 100-0245 --
# -- finished student 100-0247 --
# -- finished student 100-0248 --
# -- finished student 100-0249 --
# -- finished student 100-0250 --
# -- finished student 100-0251 --
# -- finished student 100-0252 --
# -- finished student 100-0253 --
# -- finished student 100-0255 --
# -- finished student 100-0256 --
# -- finished student 100-0259 --
# -- finished student 100-0260 --
# -- finished student 100-0261 --
# -- finished student 100-0262 --
# -- finished student 100-0263 --
# -- finished student 100-0265 --
# -- finished student 100-0266 --
# -- finished student 100-0267 --
# -- finished student 100-0269 --
# -- finished student 100-0272 --
# -- finished student 100-0273 --
# -- finished student 100-0274 --
# -- finished student 100-0275 --
# -- finished student 100-0276 --
# -- finished student 100-0278 --
# -- finished student 100-0279 --
# -- finished student 100-0280 --
# -- finished student 100-0281 --
# -- finished student 100-0282 --
# -- finished student 100-0284 --
# -- finished student 100-0285 --
# -- finished student 100-0286 --
# -- finished student 100-0287 --
# -- finished student 100-0289 --
# -- finished student 100-0290 --
# -- finished student 100-0291 --
# -- finished student 100-0292 --
# -- finished student 100-0293 --
# -- finished student 100-0294 --
# -- finished student 100-0295 --
# -- finished student 100-0296 --
# -- finished student 100-0297 --
# -- finished student 100-0298 --
# -- finished student 100-0299 --
# -- finished student 100-0300 --
# -- finished student 100-0302 --
# -- finished student 100-0303 --
# -- finished student 100-0304 --
# -- finished student 100-0305 --
# -- RESET happened for student 100-0307 --
# -- finished student 100-0307 --
# -- finished student 100-0308 --
# -- finished student 100-0309 --
# -- finished student 100-0310 --
# -- finished student 100-0311 --
# -- finished student 100-0312 --
# -- finished student 100-0314 --
# -- finished student 100-0315 --
# -- finished student 100-0316 --
# -- finished student 100-0317 --
# -- finished student 100-0319 --
# -- finished student 100-0320 --
# -- finished student 100-0321 --
# -- RESET happened for student 100-0322 --
# -- finished student 100-0322 --
# -- finished student 100-0323 --
# -- finished student 100-0324 --
# -- finished student 100-0335 --
# -- finished student 100-0336 --
# -- finished student 100-0337 --
# -- finished student 100-0338 --
# -- finished student 100-0339 --
# -- finished student 100-0340 --
# -- finished student 100-0343 --
# -- finished student 100-0345 --
# -- finished student 100-0346 --
# -- finished student 100-0347 --
# -- finished student 100-0348 --
# -- finished student 100-0349 --
# -- finished student 100-0350 --
# -- finished student 100-0351 --
# -- finished student 100-0352 --
# -- finished student 100-0354 --
# -- finished student 100-0355 --
# -- finished student 100-0356 --
# -- finished student 100-0357 --
# -- finished student 100-0358 --
# -- finished student 100-0359 --
# -- finished student 100-0361 --
# -- finished student 100-0363 --
# -- finished student 100-0364 --
# -- finished student 100-0365 --
# -- finished student 100-0366 --
# -- finished student 100-0367 --
# -- finished student 100-0368 --
# -- finished student 100-0369 --
# -- finished student 100-0370 --
# -- finished student 100-0371 --
# -- finished student 100-0372 --
# -- finished student 100-0373 --
# -- finished student 100-0374 --
# -- finished student 100-0377 --
# -- finished student 100-0378 --
# -- finished student 100-0379 --
# -- finished student 100-0380 --
# -- finished student 100-0381 --
# -- finished student 100-0382 --
# -- finished student 100-0383 --
# -- finished student 100-0384 --
# -- finished student 100-0385 --
# -- finished student 100-0387 --
# -- finished student 100-0388 --
# -- finished student 100-0389 --
# -- finished student 100-0390 --
# -- finished student 100-0391 --
# -- finished student 100-0392 --
# -- finished student 100-0395 --
# -- finished student 100-0396 --
# -- finished student 100-0397 --
# -- finished student 100-0399 --
# -- finished student 100-0401 --
# -- finished student 100-0402 --
# -- finished student 100-0403 --
# -- finished student 100-0404 --
# -- finished student 100-0406 --
# -- finished student 100-0408 --
# -- finished student 100-0411 --
# -- finished student 100-0412 --
# -- finished student 100-0413 --
# -- finished student 100-0414 --
# -- finished student 100-0416 --
# -- finished student 100-0418 --
# -- finished student 100-0420 --
# -- finished student 100-0421 --
# -- finished student 100-0422 --
# -- finished student 100-0423 --
# -- finished student 100-0424 --
# -- finished student 100-0427 --
# -- finished student 100-0428 --
# -- finished student 100-0429 --
# -- finished student 100-0431 --
# -- finished student 100-0432 --
# -- finished student 100-0433 --
# -- finished student 100-0434 --
# -- finished student 100-0436 --
# -- finished student 100-0437 --
# -- finished student 100-0438 --
# -- finished student 100-0439 --
# -- finished student 100-0440 --
# -- finished student 100-0441 --
# -- finished student 100-0442 --
# -- finished student 100-0443 --
# -- finished student 100-0444 --
# -- finished student 100-0445 --
# -- finished student 100-0446 --
# -- finished student 100-0450 --
# -- finished student 100-0451 --
# -- finished student 100-0452 --
# -- finished student 100-0453 --
# -- finished student 100-0455 --
# -- finished student 100-0456 --
# -- finished student 100-0457 --
# -- finished student 100-0458 --
# -- finished student 100-0459 --
# -- finished student 100-0460 --
# -- finished student 100-0461 --
# -- finished student 100-0462 --
# -- finished student 100-0463 --
# -- finished student 100-0464 --
# -- finished student 100-0466 --
# -- finished student 100-0468 --
# -- finished student 100-0469 --
# -- finished student 100-0471 --
# -- finished student 100-0472 --
# -- finished student 100-0473 --
# -- finished student 100-0475 --
# -- finished student 100-0476 --
# -- finished student 100-0477 --
# -- finished student 100-0478 --
# -- finished student 100-0479 --
# -- finished student 100-0482 --
# -- finished student 100-0483 --
# -- finished student 100-0484 --
# -- finished student 100-0487 --
# -- finished student 100-0488 --
# -- finished student 100-0489 --
# -- finished student 100-0490 --
# -- finished student 100-0491 --
# -- finished student 100-0492 --
# -- finished student 100-0493 --
# -- finished student 100-0494 --
# -- finished student 100-0495 --
# -- finished student 100-0496 --
# -- finished student 100-0498 --
# -- finished student 100-0499 --
# -- finished student 100-0500 --
# -- finished student 100-0501 --
# -- finished student 100-0502 --
# -- finished student 100-0504 --
# -- finished student 100-0505 --
# -- finished student 100-0506 --
# -- finished student 100-0507 --
# -- RESET happened for student 100-0508 --
# -- finished student 100-0508 --
# -- finished student 100-0509 --
# -- finished student 100-0510 --
# -- finished student 100-0511 --
# -- finished student 100-0512 --
# -- finished student 100-0513 --
# -- finished student 100-0514 --
# -- finished student 100-0515 --
# -- finished student 100-0516 --
# -- finished student 100-0827 --
# -- finished student 100-0828 --
# Actions skipped {'READ', 'AUTHENTICATE', 'SELF-REPORT', 'FINALSCORE', 'STUDY', 'COORGET', 'ADDPOINTS', 'TESTCOMPUTER', 'NOTIFICATION', 'RESET', 'STUDENTENTRY', 'STOWITEM', 'PDACLOSE', 'SOLUTION', 'RETRIEVEITEM', 'GOALCOMPLETE', 'QUIZ', 'LOOKEND'}
# Adaptions skipped {'select-offtask-discourage'}
# Removing 10 students for Restarting

# %%
# merging scores in the feature list

df_score = pd.read_csv('../raw data/training-survey-corpus.csv')
df_score = df_score[[
    'Student ID', 'Gender', 'Game-Playing Frequency', 'Content Pre Total',
    'Normalized Learning Gain'
]]
df_score = df_score.rename(
    columns={
        'Student ID': 'student_id',
        'Gender': 's_static_gender',
        'Game-Playing Frequency': 's_static_game_freq',
        'Content Pre Total': 's_static_pretest',
        'Normalized Learning Gain': 'nlg'
    })

# few nlg are NONE!
df_score = df_score.loc[df_score['nlg']!='None']
df_score['nlg'] = pd.to_numeric(df_score['nlg'])


# making sure we have nlgs for all students
df_student_data = df_student_data.loc[df_student_data['student_id'].isin(df_score['student_id'].unique())]
df_student_data = df_student_data.reset_index(drop=True)

df_narrative_data = df_narrative_data.loc[df_narrative_data['student_id'].isin(df_score['student_id'].unique())]
df_narrative_data = df_narrative_data.reset_index(drop=True)

df_score = df_score.loc[df_score['student_id'].isin(df_student_data['student_id'].unique())]


# splitting nlg based on median
mid_nlg = df_score['nlg'].describe()['50%']
df_score.loc[df_score['nlg']<mid_nlg, 'nlg'] = 0
df_score.loc[df_score['nlg']>=mid_nlg, 'nlg'] = 1


# rearrange the columns
cols = [
    'student_id', 'step', 's_static_gender', 's_static_game_freq',
    's_static_pretest', 's_time_passed', 's_talk_kim', 's_talk_quentin',
    's_talk_robert', 's_talk_ford', 's_talk_others', 's_talk_bryce',
    's_talk_teresa', 's_dialog_turn', 's_open_door', 's_close_door',
    's_view_poster', 's_take_quiz', 's_pickup_obj', 's_drop_obj', 's_test_obj',
    's_diagnosis_worksheet', 's_use_pda', 's_label_slide', 's_take_note',
    's_read_book', 's_bryce_computer', 's_end_game', 's_aes_bryce_revel',
    's_aes_bryce_symptoms', 's_aes_next_goal_prompt', 's_aes_increase_urgency',
    's_aes_kim_revel', 's_aes_knowledge_quiz', 's_aes_quentin_revel',
    's_aes_record_reminder', 's_aes_reflection_prompt',
    's_aes_teresa_symptoms', 's_aes_test_count', 's_aes_diagnosis_feedback',
    'action', 'done', 'nlg'
]

df_student_data = df_student_data.merge(df_score,
                                        on=['student_id'],
                                        how='left')

df_narrative_data = df_narrative_data.merge(df_score,
                                        on=['student_id'],
                                        how='left')

df_narrative_data = df_narrative_data[cols]
df_narrative_data
# Out:
#      student_id  step  s_static_gender  s_static_game_freq  s_static_pretest  \
# 0      100-0001     0                2                   1                 3
# 1      100-0001     1                2                   1                 3
# 2      100-0001     2                2                   1                 3
# 3      100-0001     3                2                   1                 3
# 4      100-0001     4                2                   1                 3
# ...         ...   ...              ...                 ...               ...
# 9425   100-0828    28                1                   4                 3
# 9426   100-0828    29                1                   4                 3
# 9427   100-0828    30                1                   4                 3
# 9428   100-0828    31                1                   4                 3
# 9429   100-0828    32                1                   4                 3
#
#       s_time_passed  s_talk_kim  s_talk_quentin  s_talk_robert  s_talk_ford  \
# 0             1.170           0               0              0            0
# 1           408.255           2               0              0            0
# 2           604.005           2               0              0            0
# 3           615.285           2               1              0            0
# 4           738.465           3               1              0            0
# ...             ...         ...             ...            ...          ...
# 9425       3007.365           5               4              1            1
# 9426       3048.375           5               4              1            1
# 9427       3177.330           6               4              1            1
# 9428       3326.325           7               4              1            1
# 9429       3338.610           7               4              1            1
#
#       ...  s_aes_knowledge_quiz  s_aes_quentin_revel  s_aes_record_reminder  \
# 0     ...                     0                    0                      0
# 1     ...                     0                    0                      0
# 2     ...                     0                    0                      0
# 3     ...                     2                    0                      0
# 4     ...                     0                    0                      0
# ...   ...                   ...                  ...                    ...
# 9425  ...                     0                    0                      2
# 9426  ...                     0                    0                      2
# 9427  ...                     0                    0                      0
# 9428  ...                     0                    0                      0
# 9429  ...                     0                    0                      0
#
#       s_aes_reflection_prompt  s_aes_teresa_symptoms  s_aes_test_count  \
# 0                           0                      0                 1
# 1                           0                      0                 0
# 2                           0                      0                 0
# 3                           0                      0                 0
# 4                           0                      0                 0
# ...                       ...                    ...               ...
# 9425                        0                      0                 0
# 9426                        0                      0                 0
# 9427                        0                      0                 0
# 9428                        0                      0                 0
# 9429                        1                      0                 0
#
#       s_aes_diagnosis_feedback  action   done  nlg
# 0                            0       1  False  0.0
# 1                            0       1  False  0.0
# 2                            0       2  False  0.0
# 3                            0       2  False  0.0
# 4                            2       2  False  0.0
# ...                        ...     ...    ...  ...
# 9425                         0       2  False  1.0
# 9426                         0       2  False  1.0
# 9427                         2       2  False  1.0
# 9428                         1       1  False  1.0
# 9429                         0       1   True  1.0
#
# [9430 rows x 43 columns]

# %%
df_student_data.to_pickle('../processed_data/student_trajectories.pkl')
df_narrative_data.to_pickle('../processed_data/narrative_trajectories.pkl')
df_score.to_pickle('../processed_data/scores.pkl')

# %%
x = df_score.loc[df_score['nlg']==0]['student_id'].unique()
y = df_score.loc[df_score['nlg']==1]['student_id'].unique()

l = df.loc[(df['student_id'].isin(x)) & (df['action']=='FINALSCORE')].apply(lambda z: int(z['detail'].split('-')[-1]), axis=1)
h = df.loc[(df['student_id'].isin(y)) & (df['action']=='FINALSCORE')].apply(lambda z: int(z['detail'].split('-')[-1]), axis=1)

# %%
np.mean(l), np.median(l), np.std(l), np.max(l), np.min(l)
# Out:
# (319.6453488372093, 220.5, 292.91572887530765, 1212, 0)

# %%
np.mean(h), np.median(h), np.std(h), np.max(h), np.min(h)
# Out:
# (431.1020408163265, 267.5, 372.5293849468741, 1366, 1)
