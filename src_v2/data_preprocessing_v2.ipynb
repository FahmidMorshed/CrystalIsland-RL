# %% [markdown]
# # parse logs to create state action reward from data
# see (this document for further details)[https://docs.google.com/document/d/1dwnqLLsM3YizOFxxjOR1O6U3hEZhGllhJrQLBBqrK0c/edit]

# %% [markdown]
# ## parse log in dataframe

# %%
import pandas as pd
import pickle

# read log data
with open('../raw data/training-log-corpus_v2.log', 'r') as f:
    logs = f.readlines()

last_time = 0.0
last_student = ''
action_count = 0
l = []
for i, line in enumerate(logs):
    tokens = line.split('\n')[0]
    tokens = tokens.split('|')

    line_no = tokens[0]
    student_id = tokens[1]
    if len(student_id) != 8:
        print(
            f"ERROR: in line {i}, student id length should be 8, found {len(student_id)}!"
        )
        exit(0)

    action = tokens[2]

    # starting entries do not have time
    try:
        float(tokens[3])
    except:
        tokens.insert(3, 0.0)
    time = float(tokens[3])

    if last_student != student_id:
        last_time = 0.0
        # print(f"{action_count} actions found for student {last_student}")
        action_count = 0

    # check is time is almost monotonic
    if last_time - time >= 1:
        print(
            f"ERROR: in line {i}, time is not monotonic! current action {action}. total action found {action_count}. student {student_id}"
        )

    last_time = time
    last_student = student_id
    action_count += 1

    try:
        detail = tokens[4]
    except:
        detail = ""

    try:
        detail2 = tokens[5]
    except:
        detail2 = ""

    others = "|".join(tokens[6:])

    l.append({
        'line': line_no,
        'episode': student_id,
        'action': action,
        'time': time,
        'detail': detail,
        'more_detail': detail2,
        'others': others,
        'all': line.split('\n')[0]
    })

df = pd.DataFrame(l,
                  columns=['line', 'episode', 'action', 'time', 'detail', 'more_detail', 'others', 'all'])


# for students with "RESET"
# we are keeping if student reseted after planing signifcant part of the game (>70%)
# or resetted very early (<30%)
print("-- removing reset issues --")
dlt_idx = []
student_with_reset = df.loc[df['action'] == 'RESET']['episode'].unique()
for student in student_with_reset:
    df_s = df.loc[df['episode'] == student]
    total_steps = len(df_s)
    i = df.loc[(df['episode'] == student)
               & (df['action'] == 'RESET')].index[0]
    before_reset_steps = len(df_s.loc[:i])
    percent_before_reset = round(before_reset_steps / total_steps * 100, 2)
    drop_curr = []
    if percent_before_reset < 30.0:
        drop_curr = list(df_s.loc[df_s.index[0]:i + 1].index)
    elif percent_before_reset > 70.0:
        drop_curr = list(df_s.loc[i:].index)
    else:
        drop_curr = list(df_s.index)

    print(
        "student: {0} | total_steps: {1} | reset_at: {2}({3}%) | dropping: {4}"
        .format(student, total_steps, before_reset_steps, percent_before_reset,
                len(drop_curr)))
    dlt_idx += drop_curr


df = df.drop(index=dlt_idx).reset_index(drop=True)
# Out:
# ERROR: in line 42330, time is not monotonic! current action RESET. total action found 190. student 100-0058
# ERROR: in line 62840, time is not monotonic! current action RESET. total action found 1335. student 100-0082
# ERROR: in line 64365, time is not monotonic! current action RESET. total action found 755. student 100-0084
# ERROR: in line 89782, time is not monotonic! current action RESET. total action found 354. student 100-0122
# ERROR: in line 104788, time is not monotonic! current action RESET. total action found 501. student 100-0142
# ERROR: in line 117531, time is not monotonic! current action RESET. total action found 714. student 100-0159
# ERROR: in line 142386, time is not monotonic! current action RESET. total action found 348. student 100-0195
# ERROR: in line 211235, time is not monotonic! current action RESET. total action found 705. student 100-0307
# ERROR: in line 223610, time is not monotonic! current action RESET. total action found 1021. student 100-0322
# ERROR: in line 328796, time is not monotonic! current action RESET. total action found 916. student 100-0508
# -- removing reset issues --
# student: 100-0058 | total_steps: 905 | reset_at: 191(21.1%) | dropping: 192
# student: 100-0082 | total_steps: 1462 | reset_at: 1336(91.38%) | dropping: 127
# student: 100-0084 | total_steps: 898 | reset_at: 756(84.19%) | dropping: 143
# student: 100-0122 | total_steps: 834 | reset_at: 355(42.57%) | dropping: 834
# student: 100-0142 | total_steps: 1382 | reset_at: 502(36.32%) | dropping: 1382
# student: 100-0159 | total_steps: 916 | reset_at: 715(78.06%) | dropping: 202
# student: 100-0195 | total_steps: 999 | reset_at: 349(34.93%) | dropping: 999
# student: 100-0307 | total_steps: 1397 | reset_at: 706(50.54%) | dropping: 1397
# student: 100-0322 | total_steps: 1125 | reset_at: 1022(90.84%) | dropping: 104
# student: 100-0508 | total_steps: 1254 | reset_at: 917(73.13%) | dropping: 338

# %%
# get student features
df_score = pd.read_csv('../raw data/training-survey-corpus.csv')
df_score = df_score[[
    'Student ID', 'Gender', 'Game-Playing Skill', 'Content Pre Total',
    'Normalized Learning Gain'
]]
df_score = df_score.rename(
    columns={
        'Student ID': 'episode',
        'Gender': 's_static_gender',
        'Game-Playing Skill': 's_static_gameskill',
        'Content Pre Total': 's_static_pretest',
        'Normalized Learning Gain': 'nlg'
    })

# splitting reward based on median
# few nlg are None!
df_score = df_score.loc[df_score['nlg']!='None']
df_score['nlg'] = pd.to_numeric(df_score['nlg'])
mid_nlg = df_score['nlg'].describe()['50%']
df_score.loc[df_score['nlg']<mid_nlg, 'nlg'] = -100.0
df_score.loc[df_score['nlg']>=mid_nlg, 'nlg'] = 100.0

mid_pretest = df_score['s_static_pretest'].describe()['50%']
df_score.loc[df_score['s_static_pretest']<mid_pretest, 's_static_pretest'] = 0.
df_score.loc[df_score['s_static_pretest']>=mid_pretest, 's_static_pretest'] = 1.

mid_skill = df_score['s_static_gameskill'].describe()['50%']
df_score.loc[df_score['s_static_gameskill']<mid_skill, 's_static_gameskill'] = 0.
df_score.loc[df_score['s_static_gameskill']>=mid_skill, 's_static_gameskill'] = 1.

df_score['s_static_gender'] = df_score['s_static_gender'] - 1.0

# making sure we have static features for all students
# 26 students are removed | total left 399
df = df.loc[df['episode'].isin(df_score['episode'].unique())]
df = df.reset_index(drop=True)

df = df.merge(df_score, on='episode', how='left')

# %% [markdown]
# ## parse student trajectories

# %% [markdown]
# ### define state names and their locations for student trajectories

# %%
state_names = [
    # location 5 | total 5
    "s_loc_bry", "s_loc_din", "s_loc_inf", "s_loc_lab", "s_loc_men",
    # talk 8 | total 13
    "s_talk_bry", "s_talk_eli", "s_talk_ext", "s_talk_for", "s_talk_kim",
    "s_talk_que", "s_talk_rob", "s_talk_ter",
    # poster 22 | total 35
    "s_post_ali", "s_post_ant", "s_post_bac", "s_post_bac_rep", "s_post_bac_str",
    "s_post_bac_dis", "s_post_bot", "s_post_ebo", "s_post_ele_mic", "s_post_how_pat",
    "s_post_inf", "s_post_opt_mic", "s_post_pat_mut", "s_post_pre_tre", "s_post_sal",
    "s_post_sci_met", "s_post_siz_com", "s_post_sma", "s_post_vir_dis", "s_post_vir_rep",
    "s_post_vir_str", "s_post_vir",
    # book 9 | total 44
    "s_book_ant", "s_book_bac", "s_book_bot", "s_book_ebo", "s_book_fun",
    "s_book_inf", "s_book_sal", "s_book_sma", "s_book_vir",
    # objects 17 | total 61
    "s_obj_app", "s_obj_ban", "s_obj_bre", "s_obj_cac", "s_obj_che",
    "s_obj_coc", "s_obj_egg", "s_obj_mil", "s_obj_oj", "s_obj_ora",
    "s_obj_pie", "s_obj_san", "s_obj_wat", "s_obj_ket", "s_obj_jar10",
    "s_obj_jar11", "s_obj_jar4",
    # objects tested 17 | total 78
    "s_objtest_app", "s_objtest_ban", "s_objtest_bre", "s_objtest_cac", "s_objtest_che",
    "s_objtest_coc", "s_objtest_egg", "s_objtest_mil", "s_objtest_oj", "s_objtest_ora",
    "s_objtest_pie", "s_objtest_san", "s_objtest_wat", "s_objtest_ket", "s_objtest_jar10",
    "s_objtest_jar11", "s_objtest_jar4",
    # individuals | total 89
    "s_testpos", "s_testleft", "s_label", "s_label_lesson", "s_label_slide",
    "s_worksheet", "s_workshsubmit", "s_notetake", "s_noteview", "s_computer",
    "s_quiz",
    # aes 14 | total 103
    "s_aes_bry_1", "s_aes_bry_2", "s_aes_ter_1", "s_aes_ter_2", "s_aes_ter_3",
    "s_aes_kno_1", "s_aes_kno_2", "s_aes_wor_1", "s_aes_wor_2", "s_aes_wor_3",
    "s_aes_pas_1", "s_aes_pas_2", "s_aes_que_1", "s_aes_que_2",
    # player static attributes | total 106
    "s_static_gender", "s_static_pretest", "s_static_gameskill",
    # target goal | total 108
    "s_target_disease", "s_target_item"
]

action_names = [
    # location 5 | total 5
    "a_loc_bry", "a_loc_din", "a_loc_inf", "a_loc_lab", "a_loc_men",
    # talk 8 | total 13
    "a_talk_bry", "a_talk_eli", "a_talk_ext", "a_talk_for", "a_talk_kim",
    "a_talk_que", "a_talk_rob", "a_talk_ter",
    # individual 11 | total 24
    "a_obj", "a_objtest", "a_book", "a_post", "a_notetake",
    "a_noteview", "a_computer", "a_worksheet", "a_workshsubmit", "a_label",
    "a_testleft",
]

state_map = {name:i for (i,name) in enumerate(state_names)}
action_map = {name:i for (i,name) in enumerate(action_names)}
state_map_rev = {i:name for (i,name) in enumerate(state_names)}
action_map_rev = {i:name for (i,name) in enumerate(action_names)}

post_loc_map = {
    "s_post_ali": "s_loc_lab", "s_post_ant": "s_loc_inf", "s_post_bac": "s_loc_men", "s_post_bac_rep": "s_loc_men", "s_post_bac_str": "s_loc_lab",
    "s_post_bac_dis": "s_loc_lab", "s_post_bot": "s_loc_inf", "s_post_ebo": "s_loc_inf", "s_post_ele_mic": "s_loc_lab", "s_post_how_pat": "s_loc_men",
    "s_post_inf": "s_loc_inf", "s_post_opt_mic": "s_loc_lab", "s_post_pat_mut": "s_loc_lab", "s_post_pre_tre": "s_loc_inf", "s_post_sal": "s_loc_inf",
    "s_post_sci_met": "s_loc_inf", "s_post_siz_com": "s_loc_lab", "s_post_sma": "s_loc_inf", "s_post_vir_dis": "s_loc_men", "s_post_vir_rep": "s_loc_men",
    "s_post_vir_str": "s_loc_lab", "s_post_vir": "s_loc_men",
}
# all books are at s_loc_lab
talk_loc_map = {
    "s_talk_bry": "s_loc_bry",
    "s_talk_eli": "s_loc_lab",
    "s_talk_ext": "s_loc_inf",
    "s_talk_for": "s_loc_men",
    "s_talk_kim": "s_loc_inf",
    "s_talk_que": "s_loc_din",
    "s_talk_rob": "s_loc_men",
    "s_talk_ter": "s_loc_inf",
}

obj_loc_map = {
    "s_obj_app": "s_loc_din", "s_obj_ban": "s_loc_din", "s_obj_bre": "s_loc_lab", "s_obj_cac": "s_loc_bry", "s_obj_che": "s_loc_din",
    "s_obj_coc": "s_loc_lab", "s_obj_egg": "s_loc_din", "s_obj_mil": "s_loc_din", "s_obj_oj": "s_loc_din", "s_obj_ora": "s_loc_din",
    "s_obj_pie": "s_loc_din", "s_obj_san": "s_loc_din", "s_obj_wat": "s_loc_din", "s_obj_ket": "s_loc_din", "s_obj_jar10": "s_loc_inf",
    "s_obj_jar11": "s_loc_inf", "s_obj_jar4": "s_loc_inf",
}

constants = {'state_map': state_map, 'action_map': action_map, 'post_loc_map': post_loc_map, 'talk_loc_map': talk_loc_map, 'obj_loc_map': obj_loc_map, 'state_map_rev': state_map_rev, 'action_map_rev': action_map_rev}
pickle.dump(constants, open('../processed_data/constants.pkl', 'wb'))

# %% [markdown]
# ### parse and save

# %%
from copy import deepcopy
import numpy as np

init_state = np.zeros(len(state_map))
init_state[state_map['s_label_lesson']] = 1  # label lesson is always available at the start

def set_loc(state, s_loc):
    # reset all location features and set to current one
    for f in [f for f in state_map.keys() if 's_loc_' in f]:
        state[state_map[f]] = 0
    state[state_map[s_loc]] = 1
    return state

all_logs = []
step = 0
episode = ""
nlg = 0.0
def add_step(state, action_name, extra=None):
    global step, episode, all_logs, nlg
    # print(episode, step, action_name, extra)
    curr_state = deepcopy(state)
    curr_action = action_map[action_name]
    next_state = deepcopy(state)
    reward = 0.0
    done = False
    if 'a_loc_' in action_name:
        val = action_name.split('a_loc_')[-1]
        next_state = set_loc(next_state, 's_loc_'+val)

    elif 'a_talk_' in action_name:
        val = action_name.split('a_talk_')[-1]
        next_state[state_map['s_talk_'+val]] = 1

    elif 'a_workshsubmit' == action_name:
        next_state[state_map["s_workshsubmit"]] += 1
        if extra is not None and extra[0] is True:
            reward = extra[1]
            done = True
            print("-- GAMEOVER WITH REWARD {0} --".format(reward))

    elif 'a_post' == action_name:
        next_state[state_map[extra]] = 1

    elif 'a_obj' == action_name:
        next_state[state_map[extra]] = 1

    elif 'a_label' == action_name:
        # labeling must be available
        if next_state[state_map["s_label_"+extra[0]]] == 1:
            next_state[state_map['s_label']] += 1
            # if solved, no longer available
            if extra[1] is True:
                next_state[state_map["s_label_"+extra[0]]] = 0
        else:
            # this action is not relevant. not logging anything
            return deepcopy(curr_state)

    elif 'a_objtest' == action_name:
        next_state[state_map['s_testleft']] -= 1
        if extra[0]!='s_objtest_nul':
            next_state[state_map[extra[0]]] = 1

        if extra[1] is True:
            next_state[state_map['s_testpos']] = 1

        if next_state[state_map['s_testleft']] < 0:
            print("ERROR! Test left is negative!")

    elif 'a_book' == action_name:
        next_state[state_map['s_book_'+extra]] = 1

    else:
        state_name = "s" + action_name[1:]
        next_state[state_map[state_name]] += 1

    all_logs.append({'episode':episode, 'step': step, 'state': curr_state,
                     'action': curr_action, 'reward': reward,
                     'next_state': next_state, 'done': done, 'nlg': nlg})
    step += 1
    return deepcopy(next_state)

skip_till_next = False
state = deepcopy(init_state)
for idx, row in df.iterrows():
    if episode != row['episode']:
        episode = row['episode']
        step = 0
        skip_till_next = False
        state = deepcopy(init_state)
        state[state_map['s_static_gender']] = row['s_static_gender']
        state[state_map['s_static_pretest']] = row['s_static_pretest']
        state[state_map['s_static_gameskill']] = row['s_static_gameskill']
        nlg = row['nlg']

    elif skip_till_next:
        continue

    if row['action']=='SOLUTION':
        disease, item = row['detail'].split("-")[1], row['more_detail'].split("-")[1]
        if disease == "Influenza":
            state[state_map['s_target_disease']] = 0
        elif disease == "Salmonellosis":
            state[state_map['s_target_disease']] = 1
        else:
            print("ERROR! Unknown target disease", disease, row['all'])
            break
        if item == "Egg":
            state[state_map['s_target_item']] = 0
        elif item == "Milk":
            state[state_map['s_target_item']] = 1
        elif item == "Sandwich":
            state[state_map['s_target_item']] = 2
        else:
            print("ERROR! Unknown target item", item, row['all'])
            break
        continue

    if row['action'] == 'ADAPTATION':
        if row['detail'] in ['select-kim-reveal', 'select-direct-toward-goal', 'select-record-finding', 'select-increase-urgency', 'select-reflection-prompt', 'select-offtask-discourage']:
            # kim redirects to see quentine. not important
            continue

        if row['detail'] == 'select-test-count':
            # this is not an aes i am tracking
            if row['others'] == 'selected-1':
                state[state_map['s_testleft']] = 3
            elif row['others'] == 'selected-2':
                state[state_map['s_testleft']] = 5
            elif row['others'] == 'selected-3':
                state[state_map['s_testleft']] = 10
            continue
        if row['detail'] == 'select-present-quiz':
            val = row['others'].split('-')[-1]
            aes = "s_aes_kno_" + val
            state[state_map[aes]] += 1
            continue
        print(row['all'])
        aes_name = row['detail'].split('-')[1][:3]
        val = row['others'].split('-')[-1]
        aes = "s_aes_" + aes_name + "_" + val
        state[state_map[aes]] += 1
        continue

    if row['action'] == "OPEN":
        curr_loc = row['more_detail'].split("cur-action-open-door-")[1][:3]  # all loc names are first 3 letters
        if curr_loc != "fri":
            state = add_step(state, 'a_loc_'+curr_loc)
        continue

    # ignore logs not relevant
    if row['action'] in ['AUTHENTICATE', 'PDAOPEN', 'PDACLOSE', 'OPEN', 'STUDY', 'ADDPOINTS', 'GOALCOMPLETE', 'NOTIFICATION', 'SELF-REPORT', 'LOOKEND', 'DROP', 'STOWITEM', 'RETRIEVEITEM', 'FINALSCORE', 'READ', 'CLOSE', 'STUDENTENTRY', 'COORGET']:
        continue

    if row['action'] == "TALK":
        who = row['more_detail'].split('cur-action-talk-')[1][:3] # all talk names are first 3 letters
        s_loc = talk_loc_map["s_talk_" + who]
        if state[state_map[s_loc]] != 1:
            state = add_step(state, 'a' + s_loc[1:])  # move to that location first
        state = add_step(state, 'a_talk_'+who)
        continue

    if row['action'] == "DIALOG":
        if row['more_detail']=="kim":
            if row['others'] == "Hmm,Iamnotsurethisisquiteright.":
                state = set_loc(state, 's_loc_inf')  # must be in the inf
                state = add_step(state, 'a_workshsubmit')
            elif row['others'] in ["Greatjob,yousolvedourmystery!", "Thisdiagnosismakesperfectsense!We'llstartthetreatmentplanrightaway."]:
                state = set_loc(state, 's_loc_inf')  # must be in the inf
                state = add_step(state, 'a_workshsubmit', extra=(True, 100.0))
                skip_till_next = True
        continue

    if row['action'] == "LOOKSTART":
        post = row['detail'].split('-')
        if len(post)>=3:
            post = "s_post_" + post[1][:3] + "_" + post[2][:3]
        elif len(post)==2:
            post = "s_post_" + post[1][:3]
        else:
            print("ERROR! wrong poster name", row['all'])
            break
        s_loc = post_loc_map[post]
        state = set_loc(state, s_loc)  # move to that location first
        state = add_step(state, 'a_post', extra=post)
        continue

    if row['action'] == "PICKUP":
        item = row['more_detail'].split('-')[-1]
        if item in ["1", "3", "null"]:
            continue
        elif item in ["10", "11", "4"]:
            item = "s_obj_jar" + item
        else:
            item = "s_obj_" + item[:3]

        s_loc = obj_loc_map[item]
        state = set_loc(state, s_loc)  # move to that location first
        state = add_step(state, 'a_obj', extra=item)
        continue

    if row['action'] == "NOTES":
        state = add_step(state, 'a_notetake')
        continue

    if row['action'] == "PDAUSE":
        if row['detail'] in ["notepad", "micromanual"]:
            state = add_step(state, 'a_noteview')
            continue
        elif row['detail'] in ['mainscreen', 'add-note', 'notify', 'take-quiz-prompt', 'pdamsg', 'pdamsg-quiz2', 'message-panel']:
            continue
        else:
            print("WHAT!", idx, row['all'])

    if row['action'] == "LABELING":
        type = row['detail']
        correct = row['others'].split("|")[-1]
        correct = [True if correct=="correct" else False]
        state = add_step(state, 'a_label', extra=(type, correct))
        continue

    if row['action'] == "TESTCOMPUTER":
        test_remaining = int(row['others'].split('|')[2].split('-')[1])
        if state[state_map['s_testleft']] != test_remaining:
            # there is a bug in adding new tests. sometimes added-test log is missed
            print("ERROR! Wrong number of test remains", row['all'])
            state[state_map['s_testleft']] = test_remaining

        state = set_loc(state, 's_loc_lab')  # must be in the lab
        state = add_step(state, 'a_loc_lab')
        continue

    if row['action'] == "TESTOBJECT":
        if row['detail'] in ["MultipleObjects", "NoObject"] or row['more_detail'] == "noenergy":
            continue

        item = row['detail'].split('-')[-1]
        if item in ["10", "11", "4"]:
            item = "s_objtest_jar" + item
        else:
            item = "s_objtest_" + item[:3]

        found = False
        if row['more_detail'] == "correct":
            found = True

        state = set_loc(state, 's_loc_lab')  # must be in the lab
        state = add_step(state, 'a_objtest', extra=(item, found))
        continue

    if row['action'] == "QUIZ":
        if row['detail'] == 'quiz-answer':
            if 'added-test' in row['others']:
                state = add_step(state, 'a_testleft')
            continue
        else:
            state[state_map['s_quiz']] += 1
            continue

    if row['action'] == "BOOKREAD":
        book = row['detail'][:3]
        state = set_loc(state, 's_loc_lab')  # move to lab first as all books are in lab
        state = add_step(state, action_name="a_book", extra=book)
        continue

    if row['action'] == "BRYCECOMPUTER":
        state = set_loc(state, 's_loc_bry')  # must be in the bryces quarters
        state = add_step(state, action_name="a_computer")
        continue

    if row['action'] == "WORKSHEET":
        if row['detail'] == "close-worksheet":
            state = add_step(state, action_name="a_worksheet")
        continue

    if row['action'] == "GAMEOVER":
        state = add_step(state, 'a_workshsubmit', extra=(True, -100.0))
        skip_till_next = True
        continue

df_logs = pd.DataFrame(all_logs)
df_logs.loc[df_logs['done']==False, 'nlg'] = 0.0
df_logs.to_pickle('../processed_data/student_trajectories_v2.pkl')
# Out:
# 141|100-0001|ADAPTATION|738.465|select-worksheet-level|random|selected-2
# 168|100-0001|ADAPTATION|862.080|select-quentin-reveal|random|selected-2
# 202|100-0001|ADAPTATION|967.095|select-worksheet-level|random|selected-3
# 248|100-0001|ADAPTATION|1164.675|select-bryce-symptoms-level|random|selected-1
# 253|100-0001|ADAPTATION|1215.000|select-bryce-symptoms-level|random|selected-2
# 256|100-0001|ADAPTATION|1219.410|select-bryce-symptoms-level|random|selected-1
# 352|100-0001|ADAPTATION|1606.425|select-teresa-symptoms-level|random|selected-2
# 406|100-0001|ADAPTATION|1809.165|select-worksheet-level|random|selected-1
# -- GAMEOVER WITH REWARD -100.0 --
# 917|100-0003|ADAPTATION|135.585|select-bryce-symptoms-level|random|selected-2
# 1003|100-0003|ADAPTATION|654.540|select-teresa-symptoms-level|random|selected-1
# 1213|100-0003|ADAPTATION|1663.290|select-quentin-reveal|random|selected-2
# 1528|100-0003|ADAPTATION|2928.750|select-worksheet-level|random|selected-3
# 1575|100-0003|ADAPTATION|3030.495|select-bryce-symptoms-level|random|selected-1
# 1632|100-0003|ADAPTATION|3307.110|select-worksheet-level|random|selected-2
# -- GAMEOVER WITH REWARD -100.0 --
# 1692|100-0004|ADAPTATION|236.385|select-bryce-symptoms-level|random|selected-1
# 1986|100-0004|ADAPTATION|1331.565|select-quentin-reveal|random|selected-1
# -- GAMEOVER WITH REWARD -100.0 --
# 2387|100-0005|ADAPTATION|540.855|select-bryce-symptoms-level|random|selected-2
# 2522|100-0005|ADAPTATION|954.825|select-quentin-reveal|random|selected-1
# 2578|100-0005|ADAPTATION|1148.325|select-worksheet-level|random|selected-3
# 2641|100-0005|ADAPTATION|1340.865|select-teresa-symptoms-level|random|selected-3
# 2682|100-0005|ADAPTATION|1456.755|select-worksheet-level|random|selected-1
# 2910|100-0005|ADAPTATION|2015.745|select-bryce-symptoms-level|random|selected-1
# 3020|100-0005|ADAPTATION|2320.035|select-worksheet-level|random|selected-2
# 3094|100-0005|ADAPTATION|2493.735|select-worksheet-level|random|selected-3
# -- GAMEOVER WITH REWARD 100.0 --
# 3157|100-0006|ADAPTATION|613.515|select-quentin-reveal|random|selected-2
# 3243|100-0006|ADAPTATION|975.195|select-bryce-symptoms-level|random|selected-1
# 3268|100-0006|ADAPTATION|1054.695|select-teresa-symptoms-level|random|selected-1
# 3491|100-0006|ADAPTATION|2076.825|select-bryce-symptoms-level|random|selected-2
# 3494|100-0006|ADAPTATION|2081.085|select-bryce-symptoms-level|random|selected-1
# 3618|100-0006|ADAPTATION|2543.055|select-worksheet-level|random|selected-3
# 3691|100-0006|ADAPTATION|2804.535|select-worksheet-level|random|selected-1
# 3711|100-0006|ADAPTATION|2878.545|select-worksheet-level|random|selected-2
# 3740|100-0006|ADAPTATION|2981.295|select-worksheet-level|random|selected-3
# 3768|100-0006|ADAPTATION|3097.575|select-worksheet-level|random|selected-3
# 3787|100-0006|ADAPTATION|3171.105|select-worksheet-level|random|selected-3
# -- GAMEOVER WITH REWARD 100.0 --
# 4622|100-0008|ADAPTATION|536.985|select-bryce-symptoms-level|random|selected-1
# 4633|100-0008|ADAPTATION|595.830|select-bryce-reveal|random|selected-2
# 4636|100-0008|ADAPTATION|600.450|select-bryce-symptoms-level|random|selected-2
# 4640|100-0008|ADAPTATION|604.845|select-bryce-symptoms-level|random|selected-1
# 4666|100-0008|ADAPTATION|701.955|select-quentin-reveal|random|selected-1
# 5205|100-0008|ADAPTATION|2179.080|select-worksheet-level|random|selected-3
# 5243|100-0008|ADAPTATION|2245.575|select-teresa-symptoms-level|random|selected-1
# 5272|100-0008|ADAPTATION|2337.975|select-worksheet-level|random|selected-2
# 5323|100-0008|ADAPTATION|2525.460|select-worksheet-level|random|selected-1
# -- GAMEOVER WITH REWARD 100.0 --
# 5366|100-0009|ADAPTATION|488.895|select-teresa-symptoms-level|random|selected-2
# 5723|100-0009|ADAPTATION|2166.795|select-worksheet-level|random|selected-3
# 5780|100-0009|ADAPTATION|2337.525|select-quentin-reveal|random|selected-2
# 5885|100-0009|ADAPTATION|2806.575|select-bryce-reveal|random|selected-2
# 5890|100-0009|ADAPTATION|2830.245|select-bryce-symptoms-level|random|selected-1
# 5893|100-0009|ADAPTATION|2844.285|select-bryce-symptoms-level|random|selected-1
# -- GAMEOVER WITH REWARD -100.0 --
# 7224|100-0011|ADAPTATION|544.155|select-teresa-symptoms-level|random|selected-2
# 7357|100-0011|ADAPTATION|983.565|select-bryce-symptoms-level|random|selected-1
# 7484|100-0011|ADAPTATION|1423.515|select-quentin-reveal|random|selected-1
# 7652|100-0011|ADAPTATION|1825.335|select-worksheet-level|random|selected-2
# 7742|100-0011|ADAPTATION|2092.035|select-worksheet-level|random|selected-2
# 7784|100-0011|ADAPTATION|2185.485|select-teresa-symptoms-level|random|selected-2
# ERROR! Wrong number of test remains 7899|100-0011|TESTCOMPUTER|2452.080|run-test|2447.699951|2452.085938|4.385986|testsremaining-3|Hypothesis:ContaminatedwithCarcinogens|Reason:Sickmembersdrankit
# ERROR! Wrong number of test remains 8132|100-0011|TESTCOMPUTER|2969.250|run-test|2963.784424|2969.248535|5.464111|testsremaining-1|Hypothesis:ContaminatedwithMutagens|Reason:Sickmembersdrankit
# ERROR! Wrong number of test remains 8144|100-0011|TESTCOMPUTER|2991.810|run-test|2987.909912|2991.795410|3.885498|testsremaining-1|Hypothesis:ContaminatedwithCarcinogens|Reason:Sickmembersdrankit
# 8160|100-0011|ADAPTATION|3038.415|select-bryce-symptoms-level|random|selected-1
# ERROR! Wrong number of test remains 8179|100-0011|TESTCOMPUTER|3091.530|run-test|3084.674072|3091.530029|6.855957|testsremaining-1|Hypothesis:ContaminatedwithPathogens|Reason:Sickmembersateit
# ERROR! Wrong number of test remains 8208|100-0011|TESTCOMPUTER|3152.010|run-test|3144.575928|3152.002197|7.426270|testsremaining-1|Hypothesis:ContaminatedwithCarcinogens|Reason:Sickmembersdrankit
# ERROR! Wrong number of test remains 8249|100-0011|TESTCOMPUTER|3304.920|run-test|3300.091797|3304.927490|4.835693|testsremaining-1|Hypothesis:ContaminatedwithPathogens|Reason:Itlooksdirty
# -- GAMEOVER WITH REWARD -100.0 --
# 8310|100-0012|ADAPTATION|215.265|select-teresa-symptoms-level|random|selected-1
# 8454|100-0012|ADAPTATION|801.765|select-quentin-reveal|random|selected-2
# 8481|100-0012|ADAPTATION|926.055|select-bryce-symptoms-level|random|selected-1
# 8661|100-0012|ADAPTATION|1704.315|select-teresa-symptoms-level|random|selected-1
# 8720|100-0012|ADAPTATION|1881.045|select-worksheet-level|random|selected-1
# 8806|100-0012|ADAPTATION|2206.425|select-bryce-symptoms-level|random|selected-2
# 8809|100-0012|ADAPTATION|2212.275|select-bryce-symptoms-level|random|selected-1
# 8968|100-0012|ADAPTATION|2920.965|select-worksheet-level|random|selected-3
# 8987|100-0012|ADAPTATION|2986.845|select-bryce-symptoms-level|random|selected-1
# 9000|100-0012|ADAPTATION|3019.935|select-bryce-symptoms-level|random|selected-2
# -- GAMEOVER WITH REWARD -100.0 --
# 9340|100-0013|ADAPTATION|1298.025|select-teresa-symptoms-level|random|selected-2
# 9381|100-0013|ADAPTATION|1412.355|select-teresa-symptoms-level|random|selected-2
# 9967|100-0014|ADAPTATION|436.755|select-bryce-symptoms-level|random|selected-1
# 9986|100-0014|ADAPTATION|537.645|select-teresa-symptoms-level|random|selected-1
# 10187|100-0014|ADAPTATION|1326.645|select-quentin-reveal|random|selected-1
# 10212|100-0014|ADAPTATION|1420.635|select-bryce-symptoms-level|random|selected-1
# 10230|100-0014|ADAPTATION|1535.115|select-worksheet-level|random|selected-3
# 10312|100-0014|ADAPTATION|1895.925|select-worksheet-level|random|selected-3
# 10413|100-0014|ADAPTATION|2314.335|select-worksheet-level|random|selected-2
# 10579|100-0014|ADAPTATION|2867.895|select-worksheet-level|random|selected-3
# 10624|100-0014|ADAPTATION|2974.815|select-bryce-symptoms-level|random|selected-1
# -- GAMEOVER WITH REWARD -100.0 --
# 10939|100-0016|ADAPTATION|862.065|select-teresa-symptoms-level|random|selected-3
# 11032|100-0016|ADAPTATION|1249.065|select-bryce-symptoms-level|random|selected-1
# 11275|100-0016|ADAPTATION|2085.975|select-bryce-reveal|random|selected-2
# 11306|100-0016|ADAPTATION|2256.015|select-worksheet-level|random|selected-1
# 11382|100-0016|ADAPTATION|2502.585|select-worksheet-level|random|selected-2
# -- GAMEOVER WITH REWARD 100.0 --
# 11480|100-0017|ADAPTATION|328.605|select-bryce-symptoms-level|random|selected-2
# 11538|100-0017|ADAPTATION|567.645|select-bryce-reveal|random|selected-1
# 11590|100-0017|ADAPTATION|737.295|select-worksheet-level|random|selected-1
# 11617|100-0017|ADAPTATION|776.025|select-teresa-symptoms-level|random|selected-3
# 11713|100-0017|ADAPTATION|1062.675|select-worksheet-level|random|selected-3
# ERROR! Wrong number of test remains 11836|100-0017|TESTCOMPUTER|1350.240|run-test|1343.369995|1350.254395|6.884399|testsremaining-4|Hypothesis:ContaminatedwithPathogens|Reason:Itoftencarriesdisease
# ERROR! Wrong number of test remains 11874|100-0017|TESTCOMPUTER|1443.060|run-test|1438.420288|1443.049316|4.629028|testsremaining-1|Hypothesis:ContaminatedwithMutagens|Reason:Sickmembersdrankit
# ERROR! Wrong number of test remains 11894|100-0017|TESTCOMPUTER|1471.440|run-test|1467.599976|1471.429199|3.829224|testsremaining-1|Hypothesis:ContaminatedwithCarcinogens|Reason:Sickmembersdrankit
# ERROR! Wrong number of test remains 12012|100-0017|TESTCOMPUTER|1760.670|run-test|1755.792725|1760.656738|4.864014|testsremaining-1|Hypothesis:ContaminatedwithMutagens|Reason:Sickmembersateit
# ERROR! Wrong number of test remains 12022|100-0017|TESTCOMPUTER|1775.760|run-test|1772.230225|1775.759033|3.528809|testsremaining-1|Hypothesis:ContaminatedwithMutagens|Reason:Sickmembersateit
# ERROR! Wrong number of test remains 12053|100-0017|TESTCOMPUTER|1817.010|run-test|1809.930420|1817.022949|7.092529|testsremaining-3|Hypothesis:ContaminatedwithMutagens|Reason:Itlooksdirty
# 12076|100-0017|ADAPTATION|1860.705|select-worksheet-level|random|selected-2
# ERROR! Wrong number of test remains 12190|100-0017|TESTCOMPUTER|2083.620|run-test|2079.922607|2083.611816|3.689209|testsremaining-6|Hypothesis:ContaminatedwithMutagens|Reason:Sickmembersateit
# ERROR! Wrong number of test remains 12238|100-0017|TESTCOMPUTER|2159.820|run-test|2152.350586|2159.830322|7.479736|testsremaining-1|Hypothesis:ContaminatedwithPathogens|Reason:Itlooksdirty
# ERROR! Wrong number of test remains 12268|100-0017|TESTCOMPUTER|2232.750|run-test|2226.954346|2232.764160|5.809814|testsremaining-2|Hypothesis:ContaminatedwithCarcinogens|Reason:Sickmembersdrankit
# ERROR! Wrong number of test remains 12283|100-0017|TESTCOMPUTER|2256.180|run-test|2252.159912|2256.183350|4.023438|testsremaining-1|Hypothesis:ContaminatedwithCarcinogens|Reason:Sickmembersdrankit
# ERROR! Wrong number of test remains 12313|100-0017|TESTCOMPUTER|2313.810|run-test|2309.283447|2313.802002|4.518555|testsremaining-1|Hypothesis:ContaminatedwithPathogens|Reason:Sickmembersateit
# ERROR! Wrong number of test remains 12388|100-0017|TESTCOMPUTER|2434.530|run-test|2430.912354|2434.527588|3.615234|testsremaining-3|Hypothesis:ContaminatedwithCarcinogens|Reason:Sickmembersateit
# ERROR! Wrong number of test remains 12446|100-0017|TESTCOMPUTER|2529.000|run-test|2525.554199|2528.988037|3.433838|testsremaining-3|Hypothesis:ContaminatedwithCarcinogens|Reason:Sickmembersateit
# 12488|100-0017|ADAPTATION|2609.865|select-worksheet-level|random|selected-3
# 12633|100-0017|ADAPTATION|3034.995|select-worksheet-level|random|selected-2
# 12667|100-0017|ADAPTATION|3113.985|select-worksheet-level|random|selected-2
# -- GAMEOVER WITH REWARD 100.0 --
# 12745|100-0018|ADAPTATION|267.135|select-teresa-symptoms-level|random|selected-1
# 13068|100-0018|ADAPTATION|1466.115|select-teresa-symptoms-level|random|selected-2
# 13071|100-0018|ADAPTATION|1472.655|select-teresa-symptoms-level|random|selected-2
# 13107|100-0018|ADAPTATION|1547.235|select-teresa-symptoms-level|random|selected-1
# 13258|100-0018|ADAPTATION|2108.325|select-worksheet-level|random|selected-3
# -- GAMEOVER WITH REWARD 100.0 --
# 13333|100-0019|ADAPTATION|397.755|select-teresa-symptoms-level|random|selected-2
# 13430|100-0019|ADAPTATION|722.280|select-quentin-reveal|random|selected-2
# 13452|100-0019|ADAPTATION|820.080|select-bryce-symptoms-level|random|selected-2
# 13457|100-0019|ADAPTATION|828.240|select-bryce-reveal|random|selected-1
# 13825|100-0019|ADAPTATION|2040.585|select-bryce-symptoms-level|random|selected-1
# 14131|100-0019|ADAPTATION|3017.400|select-worksheet-level|random|selected-3
# -- GAMEOVER WITH REWARD 100.0 --
# 14341|100-0020|ADAPTATION|945.345|select-bryce-symptoms-level|random|selected-2
# 14386|100-0020|ADAPTATION|1067.415|select-quentin-reveal|random|selected-1
# 14962|100-0020|ADAPTATION|2946.345|select-worksheet-level|random|selected-1
# -- GAMEOVER WITH REWARD -100.0 --
# 15424|100-0021|ADAPTATION|1337.325|select-quentin-reveal|random|selected-1
# 15524|100-0021|ADAPTATION|1609.620|select-worksheet-level|random|selected-2
# 15560|100-0021|ADAPTATION|1710.180|select-bryce-symptoms-level|random|selected-2
# 15676|100-0021|ADAPTATION|2093.880|select-worksheet-level|random|selected-3
# 15708|100-0021|ADAPTATION|2174.055|select-worksheet-level|random|selected-2
# -- GAMEOVER WITH REWARD 100.0 --
# 15769|100-0022|ADAPTATION|348.105|select-teresa-symptoms-level|random|selected-1
# 15817|100-0022|ADAPTATION|473.010|select-teresa-symptoms-level|random|selected-2
# 15917|100-0022|ADAPTATION|1023.705|select-bryce-symptoms-level|random|selected-2
# 16345|100-0022|ADAPTATION|2709.465|select-quentin-reveal|random|selected-1
# -- GAMEOVER WITH REWARD -100.0 --
# 16534|100-0024|ADAPTATION|439.395|select-bryce-symptoms-level|random|selected-1
# 16537|100-0024|ADAPTATION|454.455|select-bryce-symptoms-level|random|selected-1
# 16603|100-0024|ADAPTATION|842.775|select-teresa-symptoms-level|random|selected-1
# 16623|100-0024|ADAPTATION|907.785|select-teresa-symptoms-level|random|selected-2
# 16827|100-0024|ADAPTATION|1802.805|select-quentin-reveal|random|selected-2
# 16904|100-0024|ADAPTATION|2058.435|select-worksheet-level|random|selected-2
# 17097|100-0024|ADAPTATION|2921.715|select-worksheet-level|random|selected-2
# -- GAMEOVER WITH REWARD 100.0 --
# 17457|100-0025|ADAPTATION|1427.475|select-worksheet-level|random|selected-1
# 17515|100-0025|ADAPTATION|1656.810|select-bryce-symptoms-level|random|selected-2
# 17518|100-0025|ADAPTATION|1663.365|select-bryce-symptoms-level|random|selected-2
# 17554|100-0025|ADAPTATION|1776.330|select-teresa-symptoms-level|random|selected-1
# 17669|100-0025|ADAPTATION|2176.935|select-worksheet-level|random|selected-2
# -- GAMEOVER WITH REWARD 100.0 --
# 17881|100-0026|ADAPTATION|770.745|select-bryce-symptoms-level|random|selected-2
# 17887|100-0026|ADAPTATION|807.345|select-quentin-reveal|random|selected-1
# 18308|100-0026|ADAPTATION|2324.445|select-worksheet-level|random|selected-1
# 18468|100-0026|ADAPTATION|3044.340|select-worksheet-level|random|selected-1
# 18487|100-0026|ADAPTATION|3080.880|select-bryce-symptoms-level|random|selected-1
# -- GAMEOVER WITH REWARD -100.0 --
# 19578|100-0028|ADAPTATION|239.895|select-teresa-symptoms-level|random|selected-1
# ERROR! Wrong number of test remains 19830|100-0028|TESTCOMPUTER|1075.530|press-close|1070.566284|1075.541504|4.975220|testsremaining-8|Hypothesis:ContaminatedwithNoHypothesis|Reason:NoEntry
# ERROR! Wrong number of test remains 19877|100-0028|TESTCOMPUTER|1216.095|run-test|1210.486694|1216.102905|5.616211|testsremaining-8|Hypothesis:ContaminatedwithMutagens|Reason:Sickmembersateit
# 20124|100-0028|ADAPTATION|2736.525|select-bryce-symptoms-level|random|selected-1
# 20142|100-0028|ADAPTATION|2791.320|select-bryce-reveal|random|selected-2
# ERROR! Wrong number of test remains 20180|100-0028|TESTCOMPUTER|2903.295|run-test|2897.027344|2903.307129|6.279785|testsremaining-9|Hypothesis:ContaminatedwithMutagens|Reason:Sickmemberstouchedit
# ERROR! Wrong number of test remains 20238|100-0028|TESTCOMPUTER|3013.755|run-test|3006.918701|3013.757080|6.838379|testsremaining-4|Hypothesis:ContaminatedwithMutagens|Reason:Sickmembersdrankit
# ERROR! Wrong number of test remains 20378|100-0028|TESTCOMPUTER|3300.330|run-test|3296.673096|3300.342041|3.668945|testsremaining-3|Hypothesis:ContaminatedwithPathogens|Reason:Sickmembersdrankit
# -- GAMEOVER WITH REWARD -100.0 --
# 20558|100-0029|ADAPTATION|613.905|select-bryce-symptoms-level|random|selected-1
# 20561|100-0029|ADAPTATION|628.185|select-bryce-symptoms-level|random|selected-1
# ERROR! Wrong number of test remains 20903|100-0029|TESTCOMPUTER|1644.330|run-test|1637.789185|1644.344482|6.555298|testsremaining-2|Hypothesis:ContaminatedwithPathogens|Reason:Sickmembersdrankit
# ERROR! Wrong number of test remains 21089|100-0029|TESTCOMPUTER|2195.640|run-test|2188.649902|2195.649414|6.999512|testsremaining-9|Hypothesis:ContaminatedwithCarcinogens|Reason:Sickmembersateit
# ERROR! Wrong number of test remains 21142|100-0029|TESTCOMPUTER|2308.935|run-test|2305.125000|2308.948730|3.823730|testsremaining-2|Hypothesis:ContaminatedwithMutagens|Reason:Sickmembersateit
# 21216|100-0029|ADAPTATION|2461.200|select-teresa-symptoms-level|random|selected-2
# ERROR! Wrong number of test remains 21330|100-0029|TESTCOMPUTER|2696.055|run-test|2691.135010|2696.067627|4.932617|testsremaining-3|Hypothesis:ContaminatedwithCarcinogens|Reason:Sickmembersateit
# 21368|100-0029|ADAPTATION|2900.790|select-quentin-reveal|random|selected-2
# ERROR! Wrong number of test remains 21404|100-0029|TESTCOMPUTER|2987.595|run-test|2982.599854|2987.602783|5.002930|testsremaining-3|Hypothesis:ContaminatedwithCarcinogens|Reason:Sickmembersateit
# ERROR! Wrong number of test remains 21490|100-0029|TESTCOMPUTER|3183.555|run-test|3172.919922|3183.566650|10.646729|testsremaining-9|Hypothesis:ContaminatedwithCarcinogens|Reason:Itoftencarriesdisease
# -- GAMEOVER WITH REWARD -100.0 --
# 21732|100-0030|ADAPTATION|660.975|select-bryce-symptoms-level|random|selected-1
# 21822|100-0030|ADAPTATION|967.185|select-teresa-symptoms-level|random|selected-2
# 22091|100-0030|ADAPTATION|1715.355|select-worksheet-level|random|selected-1
# 22246|100-0030|ADAPTATION|2466.855|select-bryce-reveal|random|selected-2
# 22249|100-0030|ADAPTATION|2472.135|select-bryce-symptoms-level|random|selected-2
# 22252|100-0030|ADAPTATION|2476.845|select-bryce-symptoms-level|random|selected-2
# 22272|100-0030|ADAPTATION|2544.045|select-teresa-symptoms-level|random|selected-2
# 22472|100-0030|ADAPTATION|3059.265|select-worksheet-level|random|selected-1
# 22526|100-0030|ADAPTATION|3249.855|select-quentin-reveal|random|selected-1
# -- GAMEOVER WITH REWARD -100.0 --
# 22748|100-0031|ADAPTATION|824.355|select-teresa-symptoms-level|random|selected-1
# 22780|100-0031|ADAPTATION|941.280|select-quentin-reveal|random|selected-1
# 22918|100-0031|ADAPTATION|1443.855|select-bryce-symptoms-level|random|selected-2
# 23094|100-0031|ADAPTATION|2157.765|select-teresa-symptoms-level|random|selected-3
# -- GAMEOVER WITH REWARD -100.0 --
# 23519|100-0032|ADAPTATION|180.435|select-teresa-symptoms-level|random|selected-3
# 23528|100-0032|ADAPTATION|206.175|select-teresa-symptoms-level|random|selected-2
# 23535|100-0032|ADAPTATION|245.325|select-teresa-symptoms-level|random|selected-3
# 24063|100-0032|ADAPTATION|2382.825|select-worksheet-level|random|selected-3
# 24160|100-0032|ADAPTATION|2713.515|select-worksheet-level|random|selected-1
# -- GAMEOVER WITH REWARD 100.0 --
# 24318|100-0033|ADAPTATION|829.875|select-bryce-symptoms-level|random|selected-1
# 24396|100-0033|ADAPTATION|1182.885|select-teresa-symptoms-level|random|selected-1
# 24814|100-0033|ADAPTATION|2645.985|select-bryce-symptoms-level|random|selected-2
# 24817|100-0033|ADAPTATION|2651.985|select-bryce-symptoms-level|random|selected-2
# 24922|100-0033|ADAPTATION|3066.345|select-quentin-reveal|random|selected-2
# -- GAMEOVER WITH REWARD -100.0 --
# 25006|100-0034|ADAPTATION|206.415|select-teresa-symptoms-level|random|selected-1
# 25306|100-0034|ADAPTATION|1422.855|select-quentin-reveal|random|selected-2
# 25646|100-0034|ADAPTATION|2716.635|select-worksheet-level|random|selected-2
# -- GAMEOVER WITH REWARD 100.0 --
# 25713|100-0035|ADAPTATION|463.830|select-teresa-symptoms-level|random|selected-2
# 25765|100-0035|ADAPTATION|707.415|select-bryce-reveal|random|selected-2
# 25768|100-0035|ADAPTATION|712.860|select-bryce-symptoms-level|random|selected-1
# 26016|100-0035|ADAPTATION|1905.195|select-worksheet-level|random|selected-1
# -- GAMEOVER WITH REWARD -100.0 --
# 26406|100-0037|ADAPTATION|217.005|select-teresa-symptoms-level|random|selected-1
# 26530|100-0037|ADAPTATION|664.755|select-bryce-symptoms-level|random|selected-1
# 26622|100-0037|ADAPTATION|1028.925|select-bryce-reveal|random|selected-1
# 26696|100-0037|ADAPTATION|1335.045|select-bryce-symptoms-level|random|selected-2
# 26716|100-0037|ADAPTATION|1447.245|select-worksheet-level|random|selected-2
# 26735|100-0037|ADAPTATION|1488.285|select-teresa-symptoms-level|random|selected-3
# ERROR! Wrong number of test remains 26979|100-0037|TESTCOMPUTER|2212.020|run-test|2208.911377|2212.007080|3.095703|testsremaining-2|Hypothesis:ContaminatedwithCarcinogens|Reason:Sickmembersateit
# ERROR! Wrong number of test remains 27018|100-0037|TESTCOMPUTER|2289.540|press-close|2281.023682|2289.551758|8.528076|testsremaining-2|Hypothesis:ContaminatedwithNoHypothesis|Reason:NoEntry
# 27102|100-0037|ADAPTATION|2503.575|select-worksheet-level|random|selected-2
# ERROR! Wrong number of test remains 27256|100-0037|TESTCOMPUTER|2884.290|run-test|2879.542236|2884.296631|4.754395|testsremaining-1|Hypothesis:ContaminatedwithCarcinogens|Reason:Sickmembersateit
# ERROR! Wrong number of test remains 27283|100-0037|TESTCOMPUTER|2925.240|run-test|2919.853760|2925.250977|5.397217|testsremaining-1|Hypothesis:ContaminatedwithMutagens|Reason:Sickmembersateit
# 27311|100-0037|ADAPTATION|2999.325|select-worksheet-level|random|selected-1
# 27373|100-0037|ADAPTATION|3156.765|select-worksheet-level|random|selected-3
# 27394|100-0037|ADAPTATION|3220.305|select-teresa-symptoms-level|random|selected-2
# 27420|100-0037|ADAPTATION|3269.295|select-worksheet-level|random|selected-2
# -- GAMEOVER WITH REWARD -100.0 --
# 27543|100-0038|ADAPTATION|773.880|select-teresa-symptoms-level|random|selected-1
# 27634|100-0038|ADAPTATION|1250.535|select-bryce-symptoms-level|random|selected-2
# -- GAMEOVER WITH REWARD -100.0 --
# 28209|100-0039|ADAPTATION|134.805|select-teresa-symptoms-level|random|selected-1
# 28455|100-0039|ADAPTATION|1126.050|select-teresa-symptoms-level|random|selected-2
# 28597|100-0039|ADAPTATION|1687.650|select-worksheet-level|random|selected-3
# ERROR! Wrong number of test remains 28833|100-0039|TESTCOMPUTER|2193.645|run-test|2188.382324|2193.657715|5.275391|testsremaining-3|Hypothesis:ContaminatedwithMutagens|Reason:Sickmembersdrankit
# 28917|100-0039|ADAPTATION|2401.425|select-bryce-reveal|random|selected-1
# 29006|100-0039|ADAPTATION|2753.970|select-worksheet-level|random|selected-1
# 29099|100-0039|ADAPTATION|3003.570|select-worksheet-level|random|selected-2
# 29221|100-0039|ADAPTATION|3294.465|select-bryce-symptoms-level|random|selected-1
# -- GAMEOVER WITH REWARD -100.0 --
# 29358|100-0040|ADAPTATION|1008.120|select-bryce-symptoms-level|random|selected-2
# 29613|100-0040|ADAPTATION|2691.420|select-quentin-reveal|random|selected-1
# -- GAMEOVER WITH REWARD -100.0 --
# 29790|100-0041|ADAPTATION|249.825|select-teresa-symptoms-level|random|selected-1
# 29801|100-0041|ADAPTATION|310.785|select-teresa-symptoms-level|random|selected-1
# 29804|100-0041|ADAPTATION|317.655|select-teresa-symptoms-level|random|selected-1
# 29876|100-0041|ADAPTATION|776.835|select-bryce-symptoms-level|random|selected-1
# 29887|100-0041|ADAPTATION|811.785|select-bryce-reveal|random|selected-1
# -- GAMEOVER WITH REWARD -100.0 --
# 30529|100-0042|ADAPTATION|132.525|select-teresa-symptoms-level|random|selected-1
# 30671|100-0042|ADAPTATION|660.795|select-quentin-reveal|random|selected-1
# 30879|100-0042|ADAPTATION|1503.645|select-bryce-symptoms-level|random|selected-2
# 30883|100-0042|ADAPTATION|1509.555|select-bryce-symptoms-level|random|selected-2
# 31037|100-0042|ADAPTATION|2012.910|select-worksheet-level|random|selected-3
# ERROR! Wrong number of test remains 31167|100-0042|TESTCOMPUTER|2518.800|run-test|2510.324951|2518.800537|8.475586|testsremaining-1|Hypothesis:ContaminatedwithPathogens|Reason:Itlooksdirty
# 31297|100-0042|ADAPTATION|2918.445|select-teresa-symptoms-level|random|selected-2
# 31300|100-0042|ADAPTATION|2923.260|select-teresa-symptoms-level|random|selected-3
# 31303|100-0042|ADAPTATION|2926.380|select-teresa-symptoms-level|random|selected-3
# 31338|100-0042|ADAPTATION|3013.725|select-worksheet-level|random|selected-2
# -- GAMEOVER WITH REWARD -100.0 --
# 31578|100-0043|ADAPTATION|1096.215|select-bryce-symptoms-level|random|selected-2
# 31581|100-0043|ADAPTATION|1102.545|select-bryce-symptoms-level|random|selected-2
# 31730|100-0043|ADAPTATION|2205.150|select-bryce-symptoms-level|random|selected-1
# 31856|100-0043|ADAPTATION|2693.265|select-teresa-symptoms-level|random|selected-3
# -- GAMEOVER WITH REWARD -100.0 --
# 32048|100-0044|ADAPTATION|187.230|select-teresa-symptoms-level|random|selected-2
# 32074|100-0044|ADAPTATION|292.800|select-teresa-symptoms-level|random|selected-3
# 32183|100-0044|ADAPTATION|670.515|select-bryce-symptoms-level|random|selected-1
# 32319|100-0044|ADAPTATION|1155.615|select-quentin-reveal|random|selected-1
# 32516|100-0044|ADAPTATION|1850.925|select-worksheet-level|random|selected-1
# 32581|100-0044|ADAPTATION|2117.460|select-worksheet-level|random|selected-3
# -- GAMEOVER WITH REWARD 100.0 --
# 32666|100-0045|ADAPTATION|893.340|select-bryce-symptoms-level|random|selected-1
# 32759|100-0045|ADAPTATION|1298.985|select-teresa-symptoms-level|random|selected-2
# 32792|100-0045|ADAPTATION|1457.175|select-quentin-reveal|random|selected-1
# 32998|100-0045|ADAPTATION|2244.795|select-worksheet-level|random|selected-3
# 33019|100-0045|ADAPTATION|2323.665|select-worksheet-level|random|selected-3
# 33040|100-0045|ADAPTATION|2371.245|select-teresa-symptoms-level|random|selected-2
# 33083|100-0045|ADAPTATION|2490.090|select-bryce-symptoms-level|random|selected-1
# ERROR! Wrong number of test remains 33290|100-0045|TESTCOMPUTER|3062.670|run-test|3058.336426|3062.674316|4.337891|testsremaining-1|Hypothesis:ContaminatedwithMutagens|Reason:Sickmembersateit
# ERROR! Wrong number of test remains 33324|100-0045|TESTCOMPUTER|3143.730|run-test|3136.008301|3143.730957|7.722656|testsremaining-1|Hypothesis:ContaminatedwithPathogens|Reason:Sickmembersateit
# -- GAMEOVER WITH REWARD -100.0 --
# 33410|100-0046|ADAPTATION|123.015|select-bryce-symptoms-level|random|selected-1
# 33418|100-0046|ADAPTATION|169.185|select-bryce-symptoms-level|random|selected-1
# 33685|100-0046|ADAPTATION|1329.615|select-worksheet-level|random|selected-1
# 33764|100-0046|ADAPTATION|1680.675|select-quentin-reveal|random|selected-1
# 33834|100-0046|ADAPTATION|1926.795|select-bryce-symptoms-level|random|selected-2
# 33910|100-0046|ADAPTATION|2212.215|select-worksheet-level|random|selected-3
# 33936|100-0046|ADAPTATION|2259.765|select-teresa-symptoms-level|random|selected-3
# ERROR! Wrong number of test remains 33989|100-0046|TESTCOMPUTER|2378.850|run-test|2372.578613|2378.854248|6.275635|testsremaining-2|Hypothesis:ContaminatedwithMutagens|Reason:Sickmembersateit
# 34144|100-0046|ADAPTATION|2833.125|select-bryce-symptoms-level|random|selected-1
# ERROR! Wrong number of test remains 34235|100-0046|TESTCOMPUTER|3085.200|run-test|3081.040283|3085.188232|4.147949|testsremaining-3|Hypothesis:ContaminatedwithCarcinogens|Reason:Sickmembersateit
# -- GAMEOVER WITH REWARD -100.0 --
# 34419|100-0047|ADAPTATION|319.725|select-teresa-symptoms-level|random|selected-1
# 34723|100-0047|ADAPTATION|1206.465|select-bryce-symptoms-level|random|selected-2
# 34752|100-0047|ADAPTATION|1343.610|select-quentin-reveal|random|selected-2
# 34860|100-0047|ADAPTATION|1674.330|select-worksheet-level|random|selected-1
# ERROR! Wrong number of test remains 35329|100-0047|TESTCOMPUTER|2974.965|run-test|2969.729492|2974.966553|5.237061|testsremaining-1|Hypothesis:ContaminatedwithCarcinogens|Reason:Sickmembersdrankit
# ERROR! Wrong number of test remains 35366|100-0047|TESTCOMPUTER|3040.125|run-test|3034.694824|3040.132324|5.437500|testsremaining-1|Hypothesis:ContaminatedwithPathogens|Reason:Sickmembersdrankit
# ERROR! Wrong number of test remains 35387|100-0047|TESTCOMPUTER|3073.560|run-test|3069.104980|3073.565186|4.460205|testsremaining-1|Hypothesis:ContaminatedwithMutagens|Reason:Sickmembersdrankit
# -- GAMEOVER WITH REWARD -100.0 --
# 35565|100-0048|ADAPTATION|848.445|select-teresa-symptoms-level|random|selected-2
# 35772|100-0048|ADAPTATION|2628.135|select-teresa-symptoms-level|random|selected-2
# -- GAMEOVER WITH REWARD -100.0 --
# 36181|100-0049|ADAPTATION|1206.165|select-teresa-symptoms-level|random|selected-2
# 36286|100-0049|ADAPTATION|1472.715|select-worksheet-level|random|selected-2
# 36314|100-0049|ADAPTATION|1565.265|select-quentin-reveal|random|selected-2
# 36548|100-0049|ADAPTATION|2202.525|select-bryce-symptoms-level|random|selected-2
# 36551|100-0049|ADAPTATION|2209.065|select-bryce-symptoms-level|random|selected-1
# 36753|100-0049|ADAPTATION|2730.375|select-worksheet-level|random|selected-2
# 36930|100-0049|ADAPTATION|3230.235|select-worksheet-level|random|selected-2
# -- GAMEOVER WITH REWARD -100.0 --
# 37086|100-0050|ADAPTATION|373.710|select-bryce-symptoms-level|random|selected-2
# 37418|100-0050|ADAPTATION|1345.440|select-teresa-symptoms-level|random|selected-3
# 37468|100-0050|ADAPTATION|1486.620|select-bryce-reveal|random|selected-1
# 37703|100-0050|ADAPTATION|2260.365|select-worksheet-level|random|selected-2
# 37725|100-0050|ADAPTATION|2333.265|select-worksheet-level|random|selected-1
# 37782|100-0050|ADAPTATION|2469.075|select-worksheet-level|random|selected-3
# 37862|100-0050|ADAPTATION|2783.175|select-worksheet-level|random|selected-3
# 37929|100-0050|ADAPTATION|2990.370|select-worksheet-level|random|selected-2
# 37958|100-0050|ADAPTATION|3072.000|select-worksheet-level|random|selected-2
# 37987|100-0050|ADAPTATION|3161.055|select-worksheet-level|random|selected-2
# -- GAMEOVER WITH REWARD -100.0 --
# 38465|100-0052|ADAPTATION|2094.645|select-bryce-symptoms-level|random|selected-2
# 38468|100-0052|ADAPTATION|2100.465|select-bryce-symptoms-level|random|selected-1
# 38590|100-0052|ADAPTATION|2519.295|select-teresa-symptoms-level|random|selected-2
# 38620|100-0052|ADAPTATION|2575.005|select-worksheet-level|random|selected-1
# 38709|100-0052|ADAPTATION|2847.975|select-teresa-symptoms-level|random|selected-3
# 38826|100-0052|ADAPTATION|3175.545|select-worksheet-level|random|selected-1
# -- GAMEOVER WITH REWARD -100.0 --
# 39030|100-0053|ADAPTATION|1166.115|select-bryce-symptoms-level|random|selected-1
# 39124|100-0053|ADAPTATION|1639.875|select-bryce-reveal|random|selected-1
# 39170|100-0053|ADAPTATION|1880.955|select-worksheet-level|random|selected-2
# 39235|100-0053|ADAPTATION|2069.025|select-bryce-symptoms-level|random|selected-2
# 39365|100-0053|ADAPTATION|2571.555|select-teresa-symptoms-level|random|selected-1
# 39497|100-0053|ADAPTATION|3127.155|select-worksheet-level|random|selected-2
# 39523|100-0053|ADAPTATION|3205.005|select-bryce-symptoms-level|random|selected-1
# -- GAMEOVER WITH REWARD -100.0 --
# 39731|100-0054|ADAPTATION|979.065|select-teresa-symptoms-level|random|selected-1
# 39748|100-0054|ADAPTATION|1031.925|select-teresa-symptoms-level|random|selected-3
# 39867|100-0054|ADAPTATION|1481.355|select-quentin-reveal|random|selected-2
# 39928|100-0054|ADAPTATION|1857.675|select-bryce-symptoms-level|random|selected-1
# 40069|100-0054|ADAPTATION|2553.885|select-bryce-reveal|random|selected-1
# 40114|100-0054|ADAPTATION|2800.365|select-worksheet-level|random|selected-3
# -- GAMEOVER WITH REWARD 100.0 --
# 40263|100-0055|ADAPTATION|589.335|select-bryce-symptoms-level|random|selected-1
# 40275|100-0055|ADAPTATION|643.485|select-quentin-reveal|random|selected-1
# 40472|100-0055|ADAPTATION|1434.255|select-teresa-symptoms-level|random|selected-2
# 40672|100-0055|ADAPTATION|2319.375|select-teresa-symptoms-level|random|selected-2
# 40746|100-0055|ADAPTATION|2547.135|select-worksheet-level|random|selected-2
# -- GAMEOVER WITH REWARD 100.0 --
# 41078|100-0056|ADAPTATION|1618.425|select-bryce-symptoms-level|random|selected-2
# 41081|100-0056|ADAPTATION|1624.815|select-bryce-symptoms-level|random|selected-1
# 41178|100-0056|ADAPTATION|2065.365|select-worksheet-level|random|selected-3
# 41235|100-0056|ADAPTATION|2293.755|select-teresa-symptoms-level|random|selected-1
# ERROR! Wrong number of test remains 41519|100-0056|TESTCOMPUTER|3213.210|run-test|3208.085938|3213.196289|5.110352|testsremaining-1|Hypothesis:ContaminatedwithMutagens|Reason:Sickmembersateit
# -- GAMEOVER WITH REWARD -100.0 --
# 43117|100-0059|ADAPTATION|256.065|select-teresa-symptoms-level|random|selected-3
# 43526|100-0059|ADAPTATION|1572.135|select-worksheet-level|random|selected-2
# -- GAMEOVER WITH REWARD 100.0 --
# 43707|100-0060|ADAPTATION|1101.795|select-worksheet-level|random|selected-1
# 43747|100-0060|ADAPTATION|1269.675|select-teresa-symptoms-level|random|selected-3
# 43778|100-0060|ADAPTATION|1400.265|select-worksheet-level|random|selected-2
# 44194|100-0060|ADAPTATION|2929.935|select-worksheet-level|random|selected-1
# -- GAMEOVER WITH REWARD -100.0 --
# 44522|100-0061|ADAPTATION|861.765|select-teresa-symptoms-level|random|selected-3
# 44624|100-0061|ADAPTATION|1150.170|select-teresa-symptoms-level|random|selected-2
# 44730|100-0061|ADAPTATION|1536.690|select-worksheet-level|random|selected-3
# 44756|100-0061|ADAPTATION|1626.450|select-bryce-symptoms-level|random|selected-2
# 44763|100-0061|ADAPTATION|1647.615|select-bryce-reveal|random|selected-1
# 44863|100-0061|ADAPTATION|2115.255|select-worksheet-level|random|selected-1
# -- GAMEOVER WITH REWARD 100.0 --
# 44998|100-0062|ADAPTATION|511.335|select-bryce-symptoms-level|random|selected-1
# 45015|100-0062|ADAPTATION|589.395|select-bryce-reveal|random|selected-2
# 45018|100-0062|ADAPTATION|596.265|select-bryce-symptoms-level|random|selected-1
# 45093|100-0062|ADAPTATION|912.345|select-worksheet-level|random|selected-2
# 45128|100-0062|ADAPTATION|1007.265|select-worksheet-level|random|selected-2
# 45155|100-0062|ADAPTATION|1050.765|select-bryce-symptoms-level|random|selected-1
# 45189|100-0062|ADAPTATION|1166.625|select-bryce-symptoms-level|random|selected-1
# 45273|100-0062|ADAPTATION|1470.165|select-teresa-symptoms-level|random|selected-3
# 45333|100-0062|ADAPTATION|1639.935|select-worksheet-level|random|selected-3
# 45375|100-0062|ADAPTATION|1807.515|select-bryce-symptoms-level|random|selected-1
# 45404|100-0062|ADAPTATION|1921.425|select-quentin-reveal|random|selected-1
# ERROR! Wrong number of test remains 45591|100-0062|TESTCOMPUTER|2495.640|run-test|2492.051025|2495.639160|3.588135|testsremaining-2|Hypothesis:ContaminatedwithMutagens|Reason:Sickmembersdrankit
# ERROR! Wrong number of test remains 45689|100-0062|TESTCOMPUTER|2752.290|run-test|2748.971191|2752.301514|3.330322|testsremaining-1|Hypothesis:ContaminatedwithCarcinogens|Reason:Sickmembersdrankit
# ERROR! Wrong number of test remains 45736|100-0062|TESTCOMPUTER|2852.970|run-test|2846.357910|2852.970215|6.612305|testsremaining-2|Hypothesis:ContaminatedwithMutagens|Reason:Itlooksdirty
# ERROR! Wrong number of test remains 45849|100-0062|TESTCOMPUTER|3137.970|press-close|3133.017334|3137.982422|4.965088|testsremaining-1|Hypothesis:ContaminatedwithNoHypothesis|Reason:NoEntry
# -- GAMEOVER WITH REWARD -100.0 --
# 46062|100-0063|ADAPTATION|790.605|select-bryce-reveal|random|selected-2
# 46065|100-0063|ADAPTATION|798.135|select-bryce-symptoms-level|random|selected-2
# 46068|100-0063|ADAPTATION|803.715|select-bryce-symptoms-level|random|selected-2
# 46109|100-0063|ADAPTATION|994.185|select-quentin-reveal|random|selected-1
# 46218|100-0063|ADAPTATION|1379.895|select-teresa-symptoms-level|random|selected-3
# 46254|100-0063|ADAPTATION|1459.665|select-worksheet-level|random|selected-2
# 46287|100-0063|ADAPTATION|1553.205|select-worksheet-level|random|selected-1
# -- GAMEOVER WITH REWARD -100.0 --
# 46917|100-0064|ADAPTATION|584.265|select-bryce-symptoms-level|random|selected-2
# 46966|100-0064|ADAPTATION|701.340|select-teresa-symptoms-level|random|selected-1
# 46997|100-0064|ADAPTATION|795.645|select-quentin-reveal|random|selected-1
# 47135|100-0064|ADAPTATION|1313.100|select-worksheet-level|random|selected-1
# 47230|100-0064|ADAPTATION|1646.445|select-worksheet-level|random|selected-2
# 47380|100-0064|ADAPTATION|2193.810|select-worksheet-level|random|selected-1
# -- GAMEOVER WITH REWARD 100.0 --
# 47404|100-0065|ADAPTATION|89.295|select-teresa-symptoms-level|random|selected-3
# 47514|100-0065|ADAPTATION|413.385|select-teresa-symptoms-level|random|selected-3
# 47554|100-0065|ADAPTATION|496.215|select-worksheet-level|random|selected-1
# 47808|100-0065|ADAPTATION|1275.495|select-worksheet-level|random|selected-1
# 47968|100-0065|ADAPTATION|1629.105|select-bryce-symptoms-level|random|selected-1
# 47981|100-0065|ADAPTATION|1663.455|select-bryce-reveal|random|selected-1
# 48053|100-0065|ADAPTATION|1880.655|select-worksheet-level|random|selected-2
# -- GAMEOVER WITH REWARD 100.0 --
# 48266|100-0066|ADAPTATION|979.305|select-quentin-reveal|random|selected-1
# 48348|100-0066|ADAPTATION|1325.325|select-bryce-symptoms-level|random|selected-2
# 48373|100-0066|ADAPTATION|1492.215|select-worksheet-level|random|selected-3
# ERROR! Wrong number of test remains 48794|100-0066|TESTCOMPUTER|2523.870|run-test|2519.010986|2523.865967|4.854980|testsremaining-6|Hypothesis:ContaminatedwithPathogens|Reason:Sickmemberstouchedit
# 48830|100-0066|ADAPTATION|2652.195|select-worksheet-level|random|selected-1
# ERROR! Wrong number of test remains 48984|100-0066|TESTCOMPUTER|3186.900|run-test|3181.438965|3186.904053|5.465088|testsremaining-1|Hypothesis:ContaminatedwithCarcinogens|Reason:Itoftencarriesdisease
# 49031|100-0066|ADAPTATION|3352.935|select-worksheet-level|random|selected-2
# -- GAMEOVER WITH REWARD -100.0 --
# 49174|100-0067|ADAPTATION|725.985|select-quentin-reveal|random|selected-1
# 49319|100-0067|ADAPTATION|1353.315|select-bryce-symptoms-level|random|selected-2
# 49428|100-0067|ADAPTATION|1837.755|select-worksheet-level|random|selected-2
# ERROR! Wrong number of test remains 49741|100-0067|TESTCOMPUTER|2761.440|run-test|2756.436523|2761.434570|4.998047|testsremaining-1|Hypothesis:ContaminatedwithMutagens|Reason:Sickmembersateit
# 49867|100-0067|ADAPTATION|3100.695|select-worksheet-level|random|selected-2
# 49885|100-0067|ADAPTATION|3161.625|select-teresa-symptoms-level|random|selected-1
# 49933|100-0067|ADAPTATION|3319.155|select-worksheet-level|random|selected-3
# -- GAMEOVER WITH REWARD -100.0 --
# 49965|100-0068|ADAPTATION|120.510|select-bryce-symptoms-level|random|selected-2
# 49974|100-0068|ADAPTATION|136.965|select-bryce-symptoms-level|random|selected-2
# ERROR! Wrong number of test remains 50097|100-0068|TESTCOMPUTER|654.165|run-test|649.529968|654.165894|4.635925|testsremaining-1|Hypothesis:ContaminatedwithCarcinogens|Reason:Sickmembersateit
# ERROR! Wrong number of test remains 50358|100-0068|TESTCOMPUTER|1276.035|run-test|1271.939941|1276.044189|4.104248|testsremaining-1|Hypothesis:ContaminatedwithCarcinogens|Reason:Sickmembersateit
# 50513|100-0068|ADAPTATION|1670.520|select-worksheet-level|random|selected-2
# 50719|100-0068|ADAPTATION|2274.885|select-teresa-symptoms-level|random|selected-1
# 50726|100-0068|ADAPTATION|2296.185|select-teresa-symptoms-level|random|selected-2
# 50729|100-0068|ADAPTATION|2300.280|select-teresa-symptoms-level|random|selected-3
# 50732|100-0068|ADAPTATION|2303.640|select-teresa-symptoms-level|random|selected-3
# ERROR! Wrong number of test remains 50879|100-0068|TESTCOMPUTER|2726.115|run-test|2720.729980|2726.124023|5.394043|testsremaining-3|Hypothesis:ContaminatedwithPathogens|Reason:Sickmembersdrankit
# 50921|100-0068|ADAPTATION|2847.105|select-worksheet-level|random|selected-3
# 51054|100-0068|ADAPTATION|3295.185|select-worksheet-level|random|selected-2
# -- GAMEOVER WITH REWARD -100.0 --
# 51178|100-0069|ADAPTATION|673.725|select-bryce-symptoms-level|random|selected-1
# 51315|100-0069|ADAPTATION|1072.035|select-worksheet-level|random|selected-3
# 51351|100-0069|ADAPTATION|1166.595|select-teresa-symptoms-level|random|selected-1
# 51668|100-0069|ADAPTATION|2122.275|select-worksheet-level|random|selected-2
# 51689|100-0069|ADAPTATION|2167.965|select-bryce-reveal|random|selected-2
# 51692|100-0069|ADAPTATION|2177.355|select-bryce-symptoms-level|random|selected-1
# 51773|100-0069|ADAPTATION|2491.005|select-worksheet-level|random|selected-3
# 51821|100-0069|ADAPTATION|2744.205|select-worksheet-level|random|selected-2
# ERROR! Wrong number of test remains 51904|100-0069|TESTCOMPUTER|2951.460|run-test|2946.233887|2951.451416|5.217529|testsremaining-1|Hypothesis:ContaminatedwithMutagens|Reason:Sickmembersateit
# -- GAMEOVER WITH REWARD -100.0 --
# 52182|100-0070|ADAPTATION|964.815|select-bryce-symptoms-level|random|selected-2
# 52185|100-0070|ADAPTATION|971.175|select-bryce-symptoms-level|random|selected-2
# 52345|100-0070|ADAPTATION|2062.605|select-teresa-symptoms-level|random|selected-2
# ERROR! Wrong number of test remains 52523|100-0070|TESTCOMPUTER|2662.770|run-test|2655.613770|2662.783936|7.170166|testsremaining-1|Hypothesis:ContaminatedwithCarcinogens|Reason:Itoftencarriesdisease
# ERROR! Wrong number of test remains 52751|100-0070|TESTCOMPUTER|3139.080|run-test|3134.735107|3139.070313|4.335205|testsremaining-1|Hypothesis:ContaminatedwithPathogens|Reason:Itlooksdirty
# -- GAMEOVER WITH REWARD -100.0 --
# 53012|100-0071|ADAPTATION|567.420|select-quentin-reveal|random|selected-2
# 53180|100-0071|ADAPTATION|1196.790|select-teresa-symptoms-level|random|selected-2
# 53346|100-0071|ADAPTATION|1740.030|select-bryce-symptoms-level|random|selected-1
# ERROR! Wrong number of test remains 53618|100-0071|TESTCOMPUTER|2474.700|run-test|2467.214844|2474.713135|7.498291|testsremaining-1|Hypothesis:ContaminatedwithNoHypothesis|Reason:Sickmembersateit
# ERROR! Wrong number of test remains 53794|100-0071|TESTCOMPUTER|2878.755|run-test|2875.604980|2878.759521|3.154541|testsremaining-1|Hypothesis:ContaminatedwithMutagens|Reason:Sickmembersdrankit
# 53840|100-0071|ADAPTATION|3005.295|select-worksheet-level|random|selected-2
# 53934|100-0071|ADAPTATION|3301.725|select-worksheet-level|random|selected-3
# -- GAMEOVER WITH REWARD -100.0 --
# 54069|100-0072|ADAPTATION|622.965|select-bryce-symptoms-level|random|selected-1
# 54172|100-0072|ADAPTATION|969.315|select-teresa-symptoms-level|random|selected-1
# 54514|100-0072|ADAPTATION|2368.785|select-bryce-symptoms-level|random|selected-2
# 54540|100-0072|ADAPTATION|2498.505|select-quentin-reveal|random|selected-2
# -- GAMEOVER WITH REWARD -100.0 --
# 54975|100-0073|ADAPTATION|1568.910|select-quentin-reveal|random|selected-2
# 55072|100-0073|ADAPTATION|2037.270|select-bryce-symptoms-level|random|selected-1
# -- GAMEOVER WITH REWARD -100.0 --
# 55336|100-0074|ADAPTATION|153.825|select-bryce-symptoms-level|random|selected-1
# 55356|100-0074|ADAPTATION|251.145|select-teresa-symptoms-level|random|selected-2
# 55823|100-0074|ADAPTATION|2643.075|select-bryce-symptoms-level|random|selected-1
# 55957|100-0074|ADAPTATION|3291.765|select-worksheet-level|random|selected-2
# -- GAMEOVER WITH REWARD 100.0 --
# 55983|100-0075|ADAPTATION|100.200|select-teresa-symptoms-level|random|selected-1
# 56105|100-0075|ADAPTATION|465.975|select-bryce-symptoms-level|random|selected-2
# 56319|100-0075|ADAPTATION|1048.530|select-worksheet-level|random|selected-1
# 56430|100-0075|ADAPTATION|1312.485|select-teresa-symptoms-level|random|selected-3
# 56497|100-0075|ADAPTATION|1481.160|select-bryce-reveal|random|selected-1
# 56610|100-0075|ADAPTATION|1931.670|select-worksheet-level|random|selected-1
# 56805|100-0075|ADAPTATION|2597.340|select-worksheet-level|random|selected-2
# -- GAMEOVER WITH REWARD 100.0 --
# ERROR! Wrong number of test remains 57328|100-0076|TESTCOMPUTER|1937.010|run-test|1931.202637|1937.018677|5.816040|testsremaining-5|Hypothesis:ContaminatedwithMutagens|Reason:Sickmembersateit
# 57566|100-0076|ADAPTATION|2415.555|select-teresa-symptoms-level|random|selected-2
# ERROR! Wrong number of test remains 57747|100-0076|TESTCOMPUTER|2856.900|run-test|2851.810791|2856.889648|5.078857|testsremaining-8|Hypothesis:ContaminatedwithCarcinogens|Reason:Sickmembersateit
# 57915|100-0076|ADAPTATION|3279.945|select-worksheet-level|random|selected-3
# 57939|100-0076|ADAPTATION|3350.625|select-worksheet-level|random|selected-2
# -- GAMEOVER WITH REWARD -100.0 --
# 58131|100-0077|ADAPTATION|1867.170|select-bryce-symptoms-level|random|selected-2
# 58168|100-0077|ADAPTATION|2139.735|select-bryce-reveal|random|selected-2
# 58171|100-0077|ADAPTATION|2148.360|select-bryce-symptoms-level|random|selected-2
# 58174|100-0077|ADAPTATION|2152.230|select-bryce-symptoms-level|random|selected-1
# 58177|100-0077|ADAPTATION|2166.330|select-bryce-symptoms-level|random|selected-1
# 58305|100-0077|ADAPTATION|2622.555|select-teresa-symptoms-level|random|selected-1
# 58450|100-0077|ADAPTATION|3057.315|select-worksheet-level|random|selected-3
# ERROR! Wrong number of test remains 58538|100-0077|TESTCOMPUTER|3243.300|run-test|3239.402832|3243.308105|3.905273|testsremaining-1|Hypothesis:ContaminatedwithCarcinogens|Reason:Sickmembersateit
# -- GAMEOVER WITH REWARD -100.0 --
# 58672|100-0078|ADAPTATION|491.145|select-bryce-symptoms-level|random|selected-1
# 58745|100-0078|ADAPTATION|962.265|select-teresa-symptoms-level|random|selected-1
# 58765|100-0078|ADAPTATION|1069.575|select-worksheet-level|random|selected-2
# 58795|100-0078|ADAPTATION|1267.185|select-worksheet-level|random|selected-1
# 58810|100-0078|ADAPTATION|1308.135|select-teresa-symptoms-level|random|selected-3
# 58813|100-0078|ADAPTATION|1313.895|select-teresa-symptoms-level|random|selected-3
# 58917|100-0078|ADAPTATION|1825.605|select-quentin-reveal|random|selected-1
# 59114|100-0078|ADAPTATION|2878.395|select-worksheet-level|random|selected-3
# -- GAMEOVER WITH REWARD -100.0 --
# 59237|100-0079|ADAPTATION|80.475|select-teresa-symptoms-level|random|selected-3
# 59323|100-0079|ADAPTATION|431.625|select-bryce-symptoms-level|random|selected-2
# 59455|100-0079|ADAPTATION|1020.465|select-bryce-reveal|random|selected-1
# 59476|100-0079|ADAPTATION|1145.505|select-bryce-symptoms-level|random|selected-1
# 59521|100-0079|ADAPTATION|1290.855|select-worksheet-level|random|selected-2
# 59601|100-0079|ADAPTATION|1605.705|select-worksheet-level|random|selected-2
# 59635|100-0079|ADAPTATION|1730.385|select-worksheet-level|random|selected-2
# 59719|100-0079|ADAPTATION|2001.495|select-worksheet-level|random|selected-2
# 59812|100-0079|ADAPTATION|2273.385|select-worksheet-level|random|selected-3
# 59832|100-0079|ADAPTATION|2361.585|select-worksheet-level|random|selected-1
# 59879|100-0079|ADAPTATION|2564.535|select-worksheet-level|random|selected-1
# 59899|100-0079|ADAPTATION|2670.255|select-worksheet-level|random|selected-3
# 60037|100-0079|ADAPTATION|3135.615|select-worksheet-level|random|selected-1
# 60087|100-0079|ADAPTATION|3318.555|select-worksheet-level|random|selected-2
# -- GAMEOVER WITH REWARD 100.0 --
# 60874|100-0081|ADAPTATION|133.770|select-bryce-symptoms-level|random|selected-1
# 60914|100-0081|ADAPTATION|405.465|select-teresa-symptoms-level|random|selected-2
# 61085|100-0081|ADAPTATION|1365.960|select-bryce-symptoms-level|random|selected-1
# 61243|100-0081|ADAPTATION|2101.980|select-bryce-reveal|random|selected-1
# 61443|100-0081|ADAPTATION|3098.280|select-worksheet-level|random|selected-1
# 61480|100-0081|ADAPTATION|3248.475|select-quentin-reveal|random|selected-1
# -- GAMEOVER WITH REWARD -100.0 --
# 61588|100-0082|ADAPTATION|294.150|select-teresa-symptoms-level|random|selected-1
# 61659|100-0082|ADAPTATION|494.790|select-bryce-symptoms-level|random|selected-2
# 61679|100-0082|ADAPTATION|577.200|select-bryce-reveal|random|selected-1
# ERROR! Wrong number of test remains 62020|100-0082|TESTCOMPUTER|1488.525|run-test|1484.357544|1488.525635|4.168091|testsremaining-2|Hypothesis:ContaminatedwithCarcinogens|Reason:Sickmembersdrankit
# ERROR! Wrong number of test remains 62082|100-0082|TESTCOMPUTER|1613.970|run-test|1609.891113|1613.971191|4.080078|testsremaining-2|Hypothesis:ContaminatedwithMutagens|Reason:Sickmembersdrankit
# ERROR! Wrong number of test remains 62151|100-0082|TESTCOMPUTER|1731.510|run-test|1727.506470|1731.510742|4.004272|testsremaining-1|Hypothesis:ContaminatedwithCarcinogens|Reason:Sickmembersateit
# 62212|100-0082|ADAPTATION|1880.670|select-worksheet-level|random|selected-3
# 62258|100-0082|ADAPTATION|1974.720|select-teresa-symptoms-level|random|selected-1
# ERROR! Wrong number of test remains 62289|100-0082|TESTCOMPUTER|2065.065|run-test|2057.790527|2065.073242|7.282715|testsremaining-1|Hypothesis:ContaminatedwithPathogens|Reason:Sickmembersateit
# ...
# 312320|100-0483|ADAPTATION|1380.195|select-teresa-symptoms-level|random|selected-2
# 313064|100-0483|ADAPTATION|3247.545|select-worksheet-level|random|selected-2
# -- GAMEOVER WITH REWARD -100.0 --
# 313122|100-0484|ADAPTATION|144.900|select-bryce-symptoms-level|random|selected-1
# 313139|100-0484|ADAPTATION|259.785|select-teresa-symptoms-level|random|selected-1
# 313450|100-0484|ADAPTATION|1648.650|select-worksheet-level|random|selected-3
# 313598|100-0484|ADAPTATION|2117.685|select-worksheet-level|random|selected-1
# 313686|100-0484|ADAPTATION|2507.730|select-worksheet-level|random|selected-3
# -- GAMEOVER WITH REWARD 100.0 --
# 313749|100-0487|ADAPTATION|300.945|select-quentin-reveal|random|selected-1
# 313812|100-0487|ADAPTATION|711.450|select-teresa-symptoms-level|random|selected-2
# 314101|100-0487|ADAPTATION|2272.080|select-worksheet-level|random|selected-1
# 314271|100-0487|ADAPTATION|2979.585|select-worksheet-level|random|selected-1
# 314291|100-0487|ADAPTATION|3069.135|select-bryce-symptoms-level|random|selected-2
# -- GAMEOVER WITH REWARD -100.0 --
# 314599|100-0488|ADAPTATION|1178.535|select-worksheet-level|random|selected-2
# 314715|100-0488|ADAPTATION|1650.825|select-teresa-symptoms-level|random|selected-1
# 314753|100-0488|ADAPTATION|1769.865|select-worksheet-level|random|selected-2
# 314831|100-0488|ADAPTATION|2140.320|select-worksheet-level|random|selected-2
# 315070|100-0488|ADAPTATION|2733.540|select-worksheet-level|random|selected-2
# 315107|100-0488|ADAPTATION|2852.730|select-worksheet-level|random|selected-1
# 315238|100-0488|ADAPTATION|3189.405|select-bryce-symptoms-level|random|selected-1
# 315243|100-0488|ADAPTATION|3210.915|select-bryce-reveal|random|selected-2
# 315246|100-0488|ADAPTATION|3217.020|select-bryce-symptoms-level|random|selected-2
# 315266|100-0488|ADAPTATION|3286.710|select-worksheet-level|random|selected-1
# -- GAMEOVER WITH REWARD -100.0 --
# 315372|100-0489|ADAPTATION|458.610|select-teresa-symptoms-level|random|selected-1
# 315559|100-0489|ADAPTATION|1218.915|select-bryce-symptoms-level|random|selected-2
# 315684|100-0489|ADAPTATION|1869.000|select-quentin-reveal|random|selected-2
# -- GAMEOVER WITH REWARD -100.0 --
# 316244|100-0490|ADAPTATION|1055.580|select-bryce-reveal|random|selected-1
# 316457|100-0490|ADAPTATION|1818.990|select-teresa-symptoms-level|random|selected-3
# 316546|100-0490|ADAPTATION|2090.100|select-teresa-symptoms-level|random|selected-3
# 316646|100-0490|ADAPTATION|2420.370|select-quentin-reveal|random|selected-1
# 316788|100-0490|ADAPTATION|2927.805|select-worksheet-level|random|selected-1
# -- GAMEOVER WITH REWARD 100.0 --
# 316982|100-0491|ADAPTATION|1016.835|select-quentin-reveal|random|selected-2
# 317057|100-0491|ADAPTATION|1296.330|select-teresa-symptoms-level|random|selected-1
# 317245|100-0491|ADAPTATION|1982.865|select-worksheet-level|random|selected-1
# 317360|100-0491|ADAPTATION|2300.550|select-worksheet-level|random|selected-1
# 317403|100-0491|ADAPTATION|2469.825|select-worksheet-level|random|selected-3
# -- GAMEOVER WITH REWARD 100.0 --
# 317425|100-0492|ADAPTATION|232.410|select-bryce-symptoms-level|random|selected-1
# 317513|100-0492|ADAPTATION|734.085|select-bryce-symptoms-level|random|selected-1
# 318020|100-0492|ADAPTATION|2655.075|select-quentin-reveal|random|selected-1
# 318049|100-0492|ADAPTATION|2793.630|select-worksheet-level|random|selected-3
# -- GAMEOVER WITH REWARD -100.0 --
# 318262|100-0493|ADAPTATION|835.425|select-bryce-symptoms-level|random|selected-2
# 318354|100-0493|ADAPTATION|1683.675|select-teresa-symptoms-level|random|selected-3
# -- GAMEOVER WITH REWARD -100.0 --
# 319309|100-0495|ADAPTATION|610.365|select-bryce-symptoms-level|random|selected-2
# 319312|100-0495|ADAPTATION|618.975|select-bryce-symptoms-level|random|selected-1
# 319652|100-0495|ADAPTATION|2599.275|select-bryce-symptoms-level|random|selected-2
# 319655|100-0495|ADAPTATION|2606.325|select-bryce-symptoms-level|random|selected-1
# -- GAMEOVER WITH REWARD -100.0 --
# 320065|100-0496|ADAPTATION|1149.465|select-bryce-symptoms-level|random|selected-2
# 320068|100-0496|ADAPTATION|1156.125|select-bryce-symptoms-level|random|selected-2
# 320122|100-0496|ADAPTATION|1442.790|select-bryce-reveal|random|selected-1
# 320193|100-0496|ADAPTATION|1807.305|select-teresa-symptoms-level|random|selected-3
# 320271|100-0496|ADAPTATION|2219.595|select-worksheet-level|random|selected-2
# 320296|100-0496|ADAPTATION|2291.850|select-bryce-symptoms-level|random|selected-2
# 320459|100-0496|ADAPTATION|3075.165|select-worksheet-level|random|selected-1
# -- GAMEOVER WITH REWARD -100.0 --
# 320561|100-0498|ADAPTATION|256.620|select-teresa-symptoms-level|random|selected-2
# 320627|100-0498|ADAPTATION|550.470|select-worksheet-level|random|selected-3
# 320689|100-0498|ADAPTATION|857.340|select-bryce-symptoms-level|random|selected-1
# ERROR! Wrong number of test remains 320931|100-0498|TESTCOMPUTER|1758.600|run-test|1753.079956|1758.609741|5.529785|testsremaining-1|Hypothesis:ContaminatedwithPathogens|Reason:Sickmembersdrankit
# 320969|100-0498|ADAPTATION|1881.495|select-teresa-symptoms-level|random|selected-3
# 320972|100-0498|ADAPTATION|1885.830|select-teresa-symptoms-level|random|selected-2
# 321002|100-0498|ADAPTATION|1971.720|select-worksheet-level|random|selected-3
# 321175|100-0498|ADAPTATION|2468.640|select-bryce-reveal|random|selected-1
# 321215|100-0498|ADAPTATION|2599.920|select-quentin-reveal|random|selected-1
# 321231|100-0498|ADAPTATION|2653.410|select-worksheet-level|random|selected-1
# 321349|100-0498|ADAPTATION|3185.085|select-worksheet-level|random|selected-1
# 321372|100-0498|ADAPTATION|3261.540|select-worksheet-level|random|selected-1
# -- GAMEOVER WITH REWARD -100.0 --
# 321481|100-0499|ADAPTATION|381.780|select-teresa-symptoms-level|random|selected-1
# 321993|100-0499|ADAPTATION|1699.260|select-bryce-symptoms-level|random|selected-2
# 322482|100-0499|ADAPTATION|3084.030|select-teresa-symptoms-level|random|selected-3
# 322497|100-0499|ADAPTATION|3118.455|select-quentin-reveal|random|selected-1
# 322535|100-0499|ADAPTATION|3275.820|select-worksheet-level|random|selected-1
# -- GAMEOVER WITH REWARD -100.0 --
# 322607|100-0500|ADAPTATION|453.735|select-bryce-symptoms-level|random|selected-2
# 322610|100-0500|ADAPTATION|460.065|select-bryce-symptoms-level|random|selected-1
# 322613|100-0500|ADAPTATION|473.925|select-bryce-symptoms-level|random|selected-1
# 323043|100-0500|ADAPTATION|2092.680|select-worksheet-level|random|selected-2
# 323070|100-0500|ADAPTATION|2182.050|select-bryce-reveal|random|selected-2
# 323216|100-0500|ADAPTATION|2938.020|select-bryce-symptoms-level|random|selected-1
# 323237|100-0500|ADAPTATION|2998.050|select-quentin-reveal|random|selected-2
# 323338|100-0500|ADAPTATION|3293.805|select-worksheet-level|random|selected-2
# -- GAMEOVER WITH REWARD -100.0 --
# 323584|100-0501|ADAPTATION|2079.195|select-bryce-symptoms-level|random|selected-2
# 323660|100-0501|ADAPTATION|2455.020|select-quentin-reveal|random|selected-2
# -- GAMEOVER WITH REWARD -100.0 --
# 323888|100-0502|ADAPTATION|205.635|select-bryce-symptoms-level|random|selected-2
# 323899|100-0502|ADAPTATION|230.010|select-bryce-reveal|random|selected-2
# 323906|100-0502|ADAPTATION|244.155|select-bryce-symptoms-level|random|selected-2
# 323977|100-0502|ADAPTATION|460.410|select-teresa-symptoms-level|random|selected-2
# 324026|100-0502|ADAPTATION|554.490|select-quentin-reveal|random|selected-1
# ERROR! Wrong number of test remains 324257|100-0502|TESTCOMPUTER|1276.710|run-test|1271.309937|1276.716553|5.406616|testsremaining-3|Hypothesis:ContaminatedwithMutagens|Reason:Sickmembersateit
# ERROR! Wrong number of test remains 324314|100-0502|TESTCOMPUTER|1387.965|run-test|1383.224976|1387.965820|4.740845|testsremaining-2|Hypothesis:ContaminatedwithPathogens|Reason:Sickmembersdrankit
# ERROR! Wrong number of test remains 324341|100-0502|TESTCOMPUTER|1453.335|run-test|1449.089966|1453.346558|4.256592|testsremaining-1|Hypothesis:ContaminatedwithCarcinogens|Reason:Sickmembersdrankit
# 324361|100-0502|ADAPTATION|1484.175|select-worksheet-level|random|selected-2
# ERROR! Wrong number of test remains 324466|100-0502|TESTCOMPUTER|1729.695|run-test|1726.005005|1729.701904|3.696899|testsremaining-1|Hypothesis:ContaminatedwithCarcinogens|Reason:Sickmembersdrankit
# 324517|100-0502|ADAPTATION|1870.395|select-worksheet-level|random|selected-3
# ERROR! Wrong number of test remains 324592|100-0502|TESTCOMPUTER|2051.250|run-test|2046.554932|2051.264404|4.709473|testsremaining-3|Hypothesis:ContaminatedwithCarcinogens|Reason:Sickmembersateit
# 324736|100-0502|ADAPTATION|2411.760|select-worksheet-level|random|selected-3
# 324795|100-0502|ADAPTATION|2577.345|select-bryce-symptoms-level|random|selected-2
# 324798|100-0502|ADAPTATION|2583.585|select-bryce-symptoms-level|random|selected-2
# 324872|100-0502|ADAPTATION|2820.510|select-worksheet-level|random|selected-1
# -- GAMEOVER WITH REWARD 100.0 --
# 325048|100-0504|ADAPTATION|862.185|select-bryce-symptoms-level|random|selected-1
# 325055|100-0504|ADAPTATION|899.400|select-bryce-reveal|random|selected-1
# 325107|100-0504|ADAPTATION|1177.290|select-worksheet-level|random|selected-3
# 325145|100-0504|ADAPTATION|1260.195|select-teresa-symptoms-level|random|selected-1
# -- GAMEOVER WITH REWARD -100.0 --
# 325672|100-0505|ADAPTATION|94.755|select-bryce-symptoms-level|random|selected-2
# 325833|100-0505|ADAPTATION|997.185|select-teresa-symptoms-level|random|selected-3
# 326003|100-0505|ADAPTATION|1681.830|select-quentin-reveal|random|selected-1
# 326113|100-0505|ADAPTATION|2100.240|select-worksheet-level|random|selected-1
# 326145|100-0505|ADAPTATION|2278.290|select-worksheet-level|random|selected-1
# 326183|100-0505|ADAPTATION|2405.295|select-bryce-symptoms-level|random|selected-2
# 326186|100-0505|ADAPTATION|2411.235|select-bryce-symptoms-level|random|selected-2
# -- GAMEOVER WITH REWARD -100.0 --
# 326543|100-0506|ADAPTATION|214.065|select-bryce-symptoms-level|random|selected-1
# 326608|100-0506|ADAPTATION|567.855|select-quentin-reveal|random|selected-1
# 326744|100-0506|ADAPTATION|1260.105|select-worksheet-level|random|selected-1
# 326929|100-0506|ADAPTATION|2062.680|select-worksheet-level|random|selected-2
# 326973|100-0506|ADAPTATION|2301.870|select-bryce-symptoms-level|random|selected-1
# 326990|100-0506|ADAPTATION|2355.240|select-teresa-symptoms-level|random|selected-3
# 327197|100-0506|ADAPTATION|3254.850|select-worksheet-level|random|selected-3
# -- GAMEOVER WITH REWARD 100.0 --
# 327215|100-0507|ADAPTATION|217.935|select-bryce-symptoms-level|random|selected-1
# 327218|100-0507|ADAPTATION|235.740|select-bryce-symptoms-level|random|selected-1
# ERROR! Wrong number of test remains 327552|100-0507|TESTCOMPUTER|2022.120|run-test|2017.814941|2022.125122|4.310181|testsremaining-1|Hypothesis:ContaminatedwithPathogens|Reason:Sickmemberstouchedit
# 327661|100-0507|ADAPTATION|2453.310|select-teresa-symptoms-level|random|selected-2
# 327668|100-0507|ADAPTATION|2485.515|select-teresa-symptoms-level|random|selected-1
# 327733|100-0507|ADAPTATION|2701.830|select-worksheet-level|random|selected-1
# -- GAMEOVER WITH REWARD -100.0 --
# 327921|100-0508|ADAPTATION|179.220|select-teresa-symptoms-level|random|selected-3
# 327926|100-0508|ADAPTATION|199.065|select-teresa-symptoms-level|random|selected-3
# 328026|100-0508|ADAPTATION|479.280|select-bryce-symptoms-level|random|selected-1
# 328158|100-0508|ADAPTATION|868.455|select-quentin-reveal|random|selected-1
# 329277|100-0509|ADAPTATION|2509.650|select-bryce-symptoms-level|random|selected-2
# 329283|100-0509|ADAPTATION|2528.640|select-bryce-symptoms-level|random|selected-1
# 329286|100-0509|ADAPTATION|2545.335|select-bryce-symptoms-level|random|selected-1
# 329297|100-0509|ADAPTATION|2640.165|select-bryce-symptoms-level|random|selected-2
# 329300|100-0509|ADAPTATION|2644.530|select-bryce-symptoms-level|random|selected-2
# 329317|100-0509|ADAPTATION|2742.900|select-bryce-symptoms-level|random|selected-1
# 329364|100-0509|ADAPTATION|2947.335|select-bryce-symptoms-level|random|selected-1
# -- GAMEOVER WITH REWARD -100.0 --
# 329690|100-0510|ADAPTATION|1278.495|select-bryce-symptoms-level|random|selected-2
# 329693|100-0510|ADAPTATION|1284.480|select-bryce-symptoms-level|random|selected-2
# 329804|100-0510|ADAPTATION|1756.575|select-teresa-symptoms-level|random|selected-3
# 329924|100-0510|ADAPTATION|2204.160|select-quentin-reveal|random|selected-2
# 330185|100-0510|ADAPTATION|3240.645|select-worksheet-level|random|selected-2
# -- GAMEOVER WITH REWARD -100.0 --
# 330230|100-0511|ADAPTATION|111.240|select-bryce-symptoms-level|random|selected-2
# 330300|100-0511|ADAPTATION|393.495|select-teresa-symptoms-level|random|selected-1
# 330320|100-0511|ADAPTATION|457.020|select-teresa-symptoms-level|random|selected-3
# 330323|100-0511|ADAPTATION|461.580|select-teresa-symptoms-level|random|selected-1
# 330489|100-0511|ADAPTATION|1255.275|select-bryce-symptoms-level|random|selected-2
# 330506|100-0511|ADAPTATION|1313.295|select-bryce-reveal|random|selected-1
# 330762|100-0511|ADAPTATION|2553.420|select-bryce-symptoms-level|random|selected-2
# 330791|100-0511|ADAPTATION|2695.335|select-worksheet-level|random|selected-1
# 330813|100-0511|ADAPTATION|2797.335|select-worksheet-level|random|selected-2
# -- GAMEOVER WITH REWARD 100.0 --
# 330928|100-0512|ADAPTATION|437.220|select-bryce-symptoms-level|random|selected-1
# 331147|100-0512|ADAPTATION|1216.545|select-quentin-reveal|random|selected-2
# 331530|100-0512|ADAPTATION|2250.210|select-worksheet-level|random|selected-3
# 331567|100-0512|ADAPTATION|2309.940|select-teresa-symptoms-level|random|selected-1
# 331685|100-0512|ADAPTATION|2794.695|select-worksheet-level|random|selected-3
# -- GAMEOVER WITH REWARD 100.0 --
# 331791|100-0513|ADAPTATION|649.425|select-teresa-symptoms-level|random|selected-2
# 331798|100-0513|ADAPTATION|680.595|select-teresa-symptoms-level|random|selected-1
# 331886|100-0513|ADAPTATION|1153.830|select-worksheet-level|random|selected-2
# 331944|100-0513|ADAPTATION|1391.550|select-worksheet-level|random|selected-1
# 332032|100-0513|ADAPTATION|1815.150|select-bryce-symptoms-level|random|selected-2
# 332041|100-0513|ADAPTATION|1833.825|select-bryce-reveal|random|selected-1
# 332154|100-0513|ADAPTATION|2557.365|select-worksheet-level|random|selected-2
# 332252|100-0513|ADAPTATION|2965.425|select-worksheet-level|random|selected-2
# 332950|100-0515|ADAPTATION|943.380|select-bryce-reveal|random|selected-2
# 332953|100-0515|ADAPTATION|948.390|select-bryce-symptoms-level|random|selected-2
# 332956|100-0515|ADAPTATION|954.120|select-bryce-symptoms-level|random|selected-2
# 333253|100-0515|ADAPTATION|2345.520|select-quentin-reveal|random|selected-2
# -- GAMEOVER WITH REWARD -100.0 --
# 333441|100-0516|ADAPTATION|485.040|select-teresa-symptoms-level|random|selected-2
# 333538|100-0516|ADAPTATION|933.465|select-bryce-reveal|random|selected-1
# 333544|100-0516|ADAPTATION|950.310|select-bryce-symptoms-level|random|selected-1
# -- GAMEOVER WITH REWARD -100.0 --
# 334126|100-0827|ADAPTATION|504.135|select-teresa-symptoms-level|random|selected-1
# 334203|100-0827|ADAPTATION|738.555|select-worksheet-level|random|selected-2
# 334293|100-0827|ADAPTATION|1081.845|select-worksheet-level|random|selected-1
# 334305|100-0827|ADAPTATION|1104.885|select-teresa-symptoms-level|random|selected-1
# 334357|100-0827|ADAPTATION|1323.765|select-bryce-symptoms-level|random|selected-2
# 334360|100-0827|ADAPTATION|1328.715|select-bryce-symptoms-level|random|selected-1
# 334366|100-0827|ADAPTATION|1360.035|select-quentin-reveal|random|selected-2
# 334742|100-0827|ADAPTATION|3307.995|select-worksheet-level|random|selected-1
# -- GAMEOVER WITH REWARD -100.0 --
# 334827|100-0828|ADAPTATION|753.660|select-teresa-symptoms-level|random|selected-2
# 335242|100-0828|ADAPTATION|2064.705|select-bryce-symptoms-level|random|selected-1
# 335408|100-0828|ADAPTATION|2676.690|select-quentin-reveal|random|selected-2
# 335429|100-0828|ADAPTATION|2735.580|select-worksheet-level|random|selected-1
# 335484|100-0828|ADAPTATION|2894.430|select-worksheet-level|random|selected-1
# 335574|100-0828|ADAPTATION|3177.330|select-worksheet-level|random|selected-2
# 335629|100-0828|ADAPTATION|3326.325|select-worksheet-level|random|selected-1
# -- GAMEOVER WITH REWARD -100.0 --

# %% [markdown]
# ## parse narrative trajectories

# %% [markdown]
# ### define state action for narrative trajectories

# %%
def get_aes_trajectories(df, target_aes, state_map=state_map):
    aes_state_map = {fname: fid for fname, fid in state_map.items() if target_aes in fname}
    step = 0
    episode = ""
    logs = []

    state = None
    action = None
    prev_row = deepcopy(df.iloc[0])

    for i, row in df.iterrows():
        if row['episode'] != episode:
            if state is not None:
                # lazy add
                logs.append({'episode':episode, 'step': step, 'state': state, 'action': action, 'reward': prev_row['reward'], 'next_state': deepcopy(prev_row['state']), 'done': prev_row['done'], 'nlg': prev_row['nlg']})
                step = 0
                state = None

                prev_row = deepcopy(row)
            episode = row['episode']

        for fname, fid in aes_state_map.items():
            if row['state'][fid] != prev_row['state'][fid]:
                if state is not None:
                    # lazily waiting for next state
                    logs.append({'episode':episode, 'step': step, 'state': state, 'action': action, 'reward': prev_row['reward'], 'next_state': deepcopy(prev_row['state']), 'done': prev_row['done'], 'nlg': prev_row['nlg']})
                    step += 1

                state = deepcopy(prev_row['state'])
                action = int(fname.split(target_aes)[1]) - 1

        prev_row = deepcopy(row)

    if state is not None:
        # lazy add
        logs.append({'episode':episode, 'step': step, 'state': state, 'action': action, 'reward': prev_row['reward'], 'next_state': deepcopy(prev_row['state']), 'done': prev_row['done'], 'nlg': prev_row['nlg']})

    return pd.DataFrame(logs)

# gen narrative data
target_aeses = ["s_aes_bry_", "s_aes_ter_", "s_aes_que_", "s_aes_kno_", "s_aes_wor_", "s_aes_pas_"]
all_aes_trajectories = {}
for target_aes in target_aeses:
    df_aes = get_aes_trajectories(df_logs, target_aes)
    all_aes_trajectories[target_aes[2:-1]] = deepcopy(df_aes)

pickle.dump(all_aes_trajectories, open('../processed_data/narrative_trajectories_v2.pkl', 'wb'))

# %% [markdown]
# # random

# %%
np.random.choice(list(post_loc_map.keys()))
# Out:
# 's_post_ant'

# %%
import gym
from gym import spaces

obs_space_tup = ()
for fname, fid in state_map.items():
    if fname in ['s_testleft', 's_label', 's_worksheet', 's_workshsubmit', 's_notetake', 's_noteview', 's_computer',
                 's_quiz'] or 's_aes_' in fname:
        obs_space_tup += (spaces.Discrete(200),)
    elif fname == 's_target_item':
        obs_space_tup += (spaces.Discrete(3),)
    else:
        obs_space_tup += (spaces.Discrete(2),)
spaces.Tuple(obs_space_tup)

len(action_map)
# Out:
# 24
